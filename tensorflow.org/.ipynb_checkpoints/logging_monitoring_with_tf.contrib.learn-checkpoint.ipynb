# %% [markdown]
# ### Monitor
# - CaptureVariable: Saves a specified variables's values into a collection at every n steps of training
# - PrintTensor: Logs a specified tensor's values at every n steps of training
# - SummarySaver: Saves tf.Summary protocol buffers for a given tensor using a tf.summary.FileWriter at every n steps of training
# - ValidationMonitor: logs a specified set of evaluation metrics a t every n steps of training, and, if desired, implements early stopping under certain conditions

# %% [markdown]
# ValidationMonitors rely on saved checkpoints to perform evaluation operations, so you'll want to modify instantiation of the classifier to add a tf.contrib.learn.RunConfig that includes asve_checkpoints_secs, which specifies how many seconds should elapse between checkpoint saves during training. <br>
# Finally, remember to attach your validation_monitor, update the fit call to include a monitors param, which takes a list of all monitors to run during model training

# %% [markdown]
# NOTE: The model_dir parameter specifies an explicit directory for model data to be stored; Each time you run the code, any existing data in model_dir will be loaded, and model training will continue where it left off in the last run. To start over model training from scratch, delete model_dir befor running the code

# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

import os
import numpy as np
import tensorflow as tf
from urllib.request import urlopen

IRIS_TRAINING = "iris_training.csv"
IRIS_TRAINING_URL = "http://download.tensorflow.org/data/iris_training.csv"

IRIS_TEST = "iris_test.csv"
IRIS_TEST_URL = "http://download.tensorflow.org/data/iris_test.csv"

tf.logging.set_verbosity(tf.logging.INFO)

# %%
def main():
    # download if file doesn't exist locally
    if not os.path.exists(IRIS_TRAINING):
        raw = urlopen(IRIS_TRAINING_URL).read()
        with open(IRIS_TRAINING, "w") as f:
            f.write(raw.decode('utf-8'))
    if not os.path.exists(IRIS_TEST):
        raw = urlopen(IRIS_TEST_URL).read()
        with open(IRIS_TEST, "w") as f:
            f.write(raw.decode('utf-8'))
    
    # load datasets
    training_set = tf.contrib.learn.datasets.base.load_csv_with_header(
        filename = IRIS_TRAINING,
        target_dtype = np.int,
        features_dtype = np.float32
    )
    test_set = tf.contrib.learn.datasets.base.load_csv_with_header(
        filename = IRIS_TEST,
        target_dtype = np.int,
        features_dtype = np.float32
    )
    
    # Specify that all features have real-value data : 指连续值
    feature_columns = [tf.contrib.layers.real_valued_column("", dimension = 4)]

    
    validation_monitor = tf.contrib.learn.monitors.ValidationMonitor(test_set.data,
                                                                    test_set.target,
                                                                    every_n_steps = 50
                                                                    )
    classifier = tf.contrib.learn.DNNClassifier(feature_columns = feature_columns,
                                                hidden_units = [10, 20, 10],
                                                n_classes = 3,
                                                model_dir = "./iris_model",
                                                config = tf.contrib.learn.RunConfig(save_checkpoints_secs = 1)
                                               )
    
    # define the training input
    def get_train_inputs():
        x = tf.constant(training_set.data)
        y = tf.constant(training_set.target)
        return x, y
    
    # fit model
    classifier.fit(input_fn = get_train_inputs,
                   steps = 2000,
                   monitors = [validation_monitor]
                  )
    
    # define the test inputs
    def get_test_inputs():
        x = tf.constant(test_set.data)
        y = tf.constant(test_set.target)
        return x, y
    
    # evaluate accuracy
    accuracy_score = classifier.evaluate(input_fn = get_test_inputs, steps = 1)["accuracy"]
    print("\nTest Accuracy: {0: f}\n".format(accuracy_score))
    
    # classify two new flower samples
    def new_samples():
        return np.array(
        [[6.4, 3.2, 4.5, 1.5],
         [5.8, 3.1, 5.0, 1.7]], dtype = np.float32)
    
    predictions = list(classifier.predict(input_fn = new_samples))
    
    print(
    "New Sample, Class Prediction:    {}\n".format(predictions))

# %%
if __name__ == "__main__":
    main()
# Out:
# WARNING:tensorflow:From /Users/ihuangyiran/anaconda2/envs/py3-tf/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:267: BaseMonitor.__init__ (from tensorflow.contrib.learn.python.learn.monitors) is deprecated and will be removed after 2016-12-05.
# Instructions for updating:
# Monitors are deprecated. Please use tf.train.SessionRunHook.
# INFO:tensorflow:Using config: {'_task_type': None, '_task_id': 0, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x11d50d668>, '_master': '', '_num_ps_replicas': 0, '_num_worker_replicas': 0, '_environment': 'local', '_is_chief': True, '_evaluation_master': '', '_tf_config': gpu_options {
#   per_process_gpu_memory_fraction: 1
# }
# , '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_secs': 1, '_save_checkpoints_steps': None, '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_model_dir': None}
# WARNING:tensorflow:From /Users/ihuangyiran/anaconda2/envs/py3-tf/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/estimators/head.py:615: scalar_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.scalar. Note that tf.summary.scalar uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on the scope they are created in. Also, passing a tensor or list of tags to a scalar summary op is no longer supported.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from ./iris_model/model.ckpt-8000
# INFO:tensorflow:Saving checkpoints for 8001 into ./iris_model/model.ckpt.
# INFO:tensorflow:loss = 0.0220627, step = 8001
# WARNING:tensorflow:From /Users/ihuangyiran/anaconda2/envs/py3-tf/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:662: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with x is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From /Users/ihuangyiran/anaconda2/envs/py3-tf/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:662: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with y is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From /Users/ihuangyiran/anaconda2/envs/py3-tf/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/estimators/head.py:615: scalar_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.scalar. Note that tf.summary.scalar uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on the scope they are created in. Also, passing a tensor or list of tags to a scalar summary op is no longer supported.
# INFO:tensorflow:Starting evaluation at 2017-06-12-13:25:32
# INFO:tensorflow:Restoring parameters from ./iris_model/model.ckpt-8001
# INFO:tensorflow:Finished evaluation at 2017-06-12-13:25:33
# INFO:tensorflow:Saving dict for global step 8001: accuracy = 0.966667, global_step = 8001, loss = 0.143953
# WARNING:tensorflow:Skipping summary for global_step, must be a float or np.float32.
# INFO:tensorflow:Validation (step 8001): loss = 0.143953, accuracy = 0.966667, global_step = 8001
# INFO:tensorflow:Saving checkpoints for 8002 into ./iris_model/model.ckpt.
# WARNING:tensorflow:From /Users/ihuangyiran/anaconda2/envs/py3-tf/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:662: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with x is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From /Users/ihuangyiran/anaconda2/envs/py3-tf/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:662: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with y is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From /Users/ihuangyiran/anaconda2/envs/py3-tf/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/estimators/head.py:615: scalar_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.scalar. Note that tf.summary.scalar uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on the scope they are created in. Also, passing a tensor or list of tags to a scalar summary op is no longer supported.
# INFO:tensorflow:Starting evaluation at 2017-06-12-13:25:34
# INFO:tensorflow:Restoring parameters from ./iris_model/model.ckpt-8002
# INFO:tensorflow:Finished evaluation at 2017-06-12-13:25:34
# INFO:tensorflow:Saving dict for global step 8002: accuracy = 0.966667, global_step = 8002, loss = 0.17281
# WARNING:tensorflow:Skipping summary for global_step, must be a float or np.float32.
# INFO:tensorflow:Validation (step 8051): loss = 0.17281, accuracy = 0.966667, global_step = 8002
# INFO:tensorflow:Saving checkpoints for 8052 into ./iris_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 34.7706
# INFO:tensorflow:loss = 0.021995, step = 8101 (2.877 sec)
# WARNING:tensorflow:From /Users/ihuangyiran/anaconda2/envs/py3-tf/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:662: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with x is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From /Users/ihuangyiran/anaconda2/envs/py3-tf/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:662: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with y is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From /Users/ihuangyiran/anaconda2/envs/py3-tf/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/estimators/head.py:615: scalar_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.scalar. Note that tf.summary.scalar uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on the scope they are created in. Also, passing a tensor or list of tags to a scalar summary op is no longer supported.
# INFO:tensorflow:Starting evaluation at 2017-06-12-13:25:35
# INFO:tensorflow:Restoring parameters from ./iris_model/model.ckpt-8052
# INFO:tensorflow:Finished evaluation at 2017-06-12-13:25:36
# INFO:tensorflow:Saving dict for global step 8052: accuracy = 0.966667, global_step = 8052, loss = 0.173637
# WARNING:tensorflow:Skipping summary for global_step, must be a float or np.float32.
# INFO:tensorflow:Validation (step 8101): loss = 0.173637, accuracy = 0.966667, global_step = 8052
# INFO:tensorflow:Saving checkpoints for 8102 into ./iris_model/model.ckpt.
# WARNING:tensorflow:From /Users/ihuangyiran/anaconda2/envs/py3-tf/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:662: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with x is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From /Users/ihuangyiran/anaconda2/envs/py3-tf/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:662: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with y is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From /Users/ihuangyiran/anaconda2/envs/py3-tf/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/estimators/head.py:615: scalar_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.scalar. Note that tf.summary.scalar uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on the scope they are created in. Also, passing a tensor or list of tags to a scalar summary op is no longer supported.
# INFO:tensorflow:Starting evaluation at 2017-06-12-13:25:36
# INFO:tensorflow:Restoring parameters from ./iris_model/model.ckpt-8102
# INFO:tensorflow:Finished evaluation at 2017-06-12-13:25:37
# INFO:tensorflow:Saving dict for global step 8102: accuracy = 0.966667, global_step = 8102, loss = 0.174498
# WARNING:tensorflow:Skipping summary for global_step, must be a float or np.float32.
# INFO:tensorflow:Validation (step 8151): loss = 0.174498, accuracy = 0.966667, global_step = 8102
# INFO:tensorflow:Saving checkpoints for 8152 into ./iris_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 43.8281
# INFO:tensorflow:loss = 0.0219058, step = 8201 (2.282 sec)
# WARNING:tensorflow:From /Users/ihuangyiran/anaconda2/envs/py3-tf/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:662: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with x is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From /Users/ihuangyiran/anaconda2/envs/py3-tf/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:662: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with y is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From /Users/ihuangyiran/anaconda2/envs/py3-tf/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/estimators/head.py:615: scalar_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.scalar. Note that tf.summary.scalar uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on the scope they are created in. Also, passing a tensor or list of tags to a scalar summary op is no longer supported.
# INFO:tensorflow:Starting evaluation at 2017-06-12-13:25:38
# INFO:tensorflow:Restoring parameters from ./iris_model/model.ckpt-8152
# INFO:tensorflow:Finished evaluation at 2017-06-12-13:25:38
# INFO:tensorflow:Saving dict for global step 8152: accuracy = 0.966667, global_step = 8152, loss = 0.1755
# WARNING:tensorflow:Skipping summary for global_step, must be a float or np.float32.
# INFO:tensorflow:Validation (step 8201): loss = 0.1755, accuracy = 0.966667, global_step = 8152
# INFO:tensorflow:Saving checkpoints for 8202 into ./iris_model/model.ckpt.
# WARNING:tensorflow:From /Users/ihuangyiran/anaconda2/envs/py3-tf/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:662: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with x is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From /Users/ihuangyiran/anaconda2/envs/py3-tf/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:662: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with y is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From /Users/ihuangyiran/anaconda2/envs/py3-tf/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/estimators/head.py:615: scalar_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.scalar. Note that tf.summary.scalar uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on the scope they are created in. Also, passing a tensor or list of tags to a scalar summary op is no longer supported.
# INFO:tensorflow:Starting evaluation at 2017-06-12-13:25:39
# INFO:tensorflow:Restoring parameters from ./iris_model/model.ckpt-8202
# INFO:tensorflow:Finished evaluation at 2017-06-12-13:25:39
# INFO:tensorflow:Saving dict for global step 8202: accuracy = 0.966667, global_step = 8202, loss = 0.176022
# WARNING:tensorflow:Skipping summary for global_step, must be a float or np.float32.
# INFO:tensorflow:Validation (step 8251): loss = 0.176022, accuracy = 0.966667, global_step = 8202
# INFO:tensorflow:Saving checkpoints for 8252 into ./iris_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 40.3786
# INFO:tensorflow:loss = 0.0218945, step = 8301 (2.477 sec)
# WARNING:tensorflow:From /Users/ihuangyiran/anaconda2/envs/py3-tf/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:662: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with x is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From /Users/ihuangyiran/anaconda2/envs/py3-tf/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:662: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with y is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From /Users/ihuangyiran/anaconda2/envs/py3-tf/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/estimators/head.py:615: scalar_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.scalar. Note that tf.summary.scalar uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on the scope they are created in. Also, passing a tensor or list of tags to a scalar summary op is no longer supported.
# INFO:tensorflow:Starting evaluation at 2017-06-12-13:25:40
# INFO:tensorflow:Restoring parameters from ./iris_model/model.ckpt-8252
# INFO:tensorflow:Finished evaluation at 2017-06-12-13:25:40
# INFO:tensorflow:Saving dict for global step 8252: accuracy = 0.966667, global_step = 8252, loss = 0.176481
# WARNING:tensorflow:Skipping summary for global_step, must be a float or np.float32.
# INFO:tensorflow:Validation (step 8301): loss = 0.176481, accuracy = 0.966667, global_step = 8252
# INFO:tensorflow:Saving checkpoints for 8302 into ./iris_model/model.ckpt.
# WARNING:tensorflow:From /Users/ihuangyiran/anaconda2/envs/py3-tf/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:662: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with x is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From /Users/ihuangyiran/anaconda2/envs/py3-tf/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:662: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with y is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From /Users/ihuangyiran/anaconda2/envs/py3-tf/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/estimators/head.py:615: scalar_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.scalar. Note that tf.summary.scalar uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on the scope they are created in. Also, passing a tensor or list of tags to a scalar summary op is no longer supported.
# INFO:tensorflow:Starting evaluation at 2017-06-12-13:25:41
# INFO:tensorflow:Restoring parameters from ./iris_model/model.ckpt-8302
# INFO:tensorflow:Finished evaluation at 2017-06-12-13:25:41
# INFO:tensorflow:Saving dict for global step 8302: accuracy = 0.966667, global_step = 8302, loss = 0.17728
# WARNING:tensorflow:Skipping summary for global_step, must be a float or np.float32.
# INFO:tensorflow:Validation (step 8351): loss = 0.17728, accuracy = 0.966667, global_step = 8302
# INFO:tensorflow:Saving checkpoints for 8352 into ./iris_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 45.9697
# INFO:tensorflow:loss = 0.0218613, step = 8401 (2.175 sec)
# WARNING:tensorflow:From /Users/ihuangyiran/anaconda2/envs/py3-tf/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:662: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with x is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From /Users/ihuangyiran/anaconda2/envs/py3-tf/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:662: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with y is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From /Users/ihuangyiran/anaconda2/envs/py3-tf/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/estimators/head.py:615: scalar_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.scalar. Note that tf.summary.scalar uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on the scope they are created in. Also, passing a tensor or list of tags to a scalar summary op is no longer supported.
# INFO:tensorflow:Starting evaluation at 2017-06-12-13:25:42
# INFO:tensorflow:Restoring parameters from ./iris_model/model.ckpt-8352
# INFO:tensorflow:Finished evaluation at 2017-06-12-13:25:42
# INFO:tensorflow:Saving dict for global step 8352: accuracy = 0.966667, global_step = 8352, loss = 0.178095
# WARNING:tensorflow:Skipping summary for global_step, must be a float or np.float32.
# INFO:tensorflow:Validation (step 8401): loss = 0.178095, accuracy = 0.966667, global_step = 8352
# INFO:tensorflow:Saving checkpoints for 8429 into ./iris_model/model.ckpt.
# WARNING:tensorflow:From /Users/ihuangyiran/anaconda2/envs/py3-tf/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:662: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with x is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From /Users/ihuangyiran/anaconda2/envs/py3-tf/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:662: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with y is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From /Users/ihuangyiran/anaconda2/envs/py3-tf/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/estimators/head.py:615: scalar_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.scalar. Note that tf.summary.scalar uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on the scope they are created in. Also, passing a tensor or list of tags to a scalar summary op is no longer supported.
# INFO:tensorflow:Starting evaluation at 2017-06-12-13:25:43
# INFO:tensorflow:Restoring parameters from ./iris_model/model.ckpt-8429
# INFO:tensorflow:Finished evaluation at 2017-06-12-13:25:44
# INFO:tensorflow:Saving dict for global step 8429: accuracy = 0.966667, global_step = 8429, loss = 0.152137
# WARNING:tensorflow:Skipping summary for global_step, must be a float or np.float32.
# INFO:tensorflow:Validation (step 8451): loss = 0.152137, accuracy = 0.966667, global_step = 8429
# INFO:tensorflow:Saving checkpoints for 8452 into ./iris_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 46.8113
# INFO:tensorflow:loss = 0.0217963, step = 8501 (2.136 sec)
# WARNING:tensorflow:From /Users/ihuangyiran/anaconda2/envs/py3-tf/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:662: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with x is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From /Users/ihuangyiran/anaconda2/envs/py3-tf/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:662: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with y is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From /Users/ihuangyiran/anaconda2/envs/py3-tf/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/estimators/head.py:615: scalar_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.scalar. Note that tf.summary.scalar uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on the scope they are created in. Also, passing a tensor or list of tags to a scalar summary op is no longer supported.
# INFO:tensorflow:Starting evaluation at 2017-06-12-13:25:44
# INFO:tensorflow:Restoring parameters from ./iris_model/model.ckpt-8452
# INFO:tensorflow:Finished evaluation at 2017-06-12-13:25:45
# INFO:tensorflow:Saving dict for global step 8452: accuracy = 0.966667, global_step = 8452, loss = 0.180128
# WARNING:tensorflow:Skipping summary for global_step, must be a float or np.float32.
# INFO:tensorflow:Validation (step 8501): loss = 0.180128, accuracy = 0.966667, global_step = 8452
# INFO:tensorflow:Saving checkpoints for 8502 into ./iris_model/model.ckpt.
# WARNING:tensorflow:From /Users/ihuangyiran/anaconda2/envs/py3-tf/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:662: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with x is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From /Users/ihuangyiran/anaconda2/envs/py3-tf/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:662: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with y is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From /Users/ihuangyiran/anaconda2/envs/py3-tf/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/estimators/head.py:615: scalar_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.scalar. Note that tf.summary.scalar uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on the scope they are created in. Also, passing a tensor or list of tags to a scalar summary op is no longer supported.
# INFO:tensorflow:Starting evaluation at 2017-06-12-13:25:45
# INFO:tensorflow:Restoring parameters from ./iris_model/model.ckpt-8502
# INFO:tensorflow:Finished evaluation at 2017-06-12-13:25:46
# INFO:tensorflow:Saving dict for global step 8502: accuracy = 0.966667, global_step = 8502, loss = 0.1806
# WARNING:tensorflow:Skipping summary for global_step, must be a float or np.float32.
# INFO:tensorflow:Validation (step 8551): loss = 0.1806, accuracy = 0.966667, global_step = 8502
# INFO:tensorflow:Saving checkpoints for 8552 into ./iris_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 43.7564
# INFO:tensorflow:loss = 0.021701, step = 8601 (2.285 sec)
# WARNING:tensorflow:From /Users/ihuangyiran/anaconda2/envs/py3-tf/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:662: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with x is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From /Users/ihuangyiran/anaconda2/envs/py3-tf/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:662: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with y is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From /Users/ihuangyiran/anaconda2/envs/py3-tf/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/estimators/head.py:615: scalar_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.scalar. Note that tf.summary.scalar uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on the scope they are created in. Also, passing a tensor or list of tags to a scalar summary op is no longer supported.
# INFO:tensorflow:Starting evaluation at 2017-06-12-13:25:47
# INFO:tensorflow:Restoring parameters from ./iris_model/model.ckpt-8552
# INFO:tensorflow:Finished evaluation at 2017-06-12-13:25:47
# INFO:tensorflow:Saving dict for global step 8552: accuracy = 0.966667, global_step = 8552, loss = 0.181198
# WARNING:tensorflow:Skipping summary for global_step, must be a float or np.float32.
# INFO:tensorflow:Validation (step 8601): loss = 0.181198, accuracy = 0.966667, global_step = 8552
# INFO:tensorflow:Saving checkpoints for 8602 into ./iris_model/model.ckpt.
# WARNING:tensorflow:From /Users/ihuangyiran/anaconda2/envs/py3-tf/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:662: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with x is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From /Users/ihuangyiran/anaconda2/envs/py3-tf/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:662: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with y is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From /Users/ihuangyiran/anaconda2/envs/py3-tf/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/estimators/head.py:615: scalar_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.scalar. Note that tf.summary.scalar uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on the scope they are created in. Also, passing a tensor or list of tags to a scalar summary op is no longer supported.
# INFO:tensorflow:Starting evaluation at 2017-06-12-13:25:48
# INFO:tensorflow:Restoring parameters from ./iris_model/model.ckpt-8602
# INFO:tensorflow:Finished evaluation at 2017-06-12-13:25:48
# INFO:tensorflow:Saving dict for global step 8602: accuracy = 0.966667, global_step = 8602, loss = 0.182026
# WARNING:tensorflow:Skipping summary for global_step, must be a float or np.float32.
# INFO:tensorflow:Validation (step 8651): loss = 0.182026, accuracy = 0.966667, global_step = 8602
# INFO:tensorflow:Saving checkpoints for 8652 into ./iris_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 45.1586
# INFO:tensorflow:loss = 0.0215825, step = 8701 (2.215 sec)
# WARNING:tensorflow:From /Users/ihuangyiran/anaconda2/envs/py3-tf/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:662: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with x is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From /Users/ihuangyiran/anaconda2/envs/py3-tf/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:662: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with y is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From /Users/ihuangyiran/anaconda2/envs/py3-tf/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/estimators/head.py:615: scalar_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.scalar. Note that tf.summary.scalar uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on the scope they are created in. Also, passing a tensor or list of tags to a scalar summary op is no longer supported.
# INFO:tensorflow:Starting evaluation at 2017-06-12-13:25:49
# INFO:tensorflow:Restoring parameters from ./iris_model/model.ckpt-8652
# INFO:tensorflow:Finished evaluation at 2017-06-12-13:25:49
# INFO:tensorflow:Saving dict for global step 8652: accuracy = 0.966667, global_step = 8652, loss = 0.1828
# WARNING:tensorflow:Skipping summary for global_step, must be a float or np.float32.
# INFO:tensorflow:Validation (step 8701): loss = 0.1828, accuracy = 0.966667, global_step = 8652
# INFO:tensorflow:Saving checkpoints for 8702 into ./iris_model/model.ckpt.
# WARNING:tensorflow:From /Users/ihuangyiran/anaconda2/envs/py3-tf/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:662: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with x is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From /Users/ihuangyiran/anaconda2/envs/py3-tf/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:662: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with y is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From /Users/ihuangyiran/anaconda2/envs/py3-tf/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/estimators/head.py:615: scalar_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.scalar. Note that tf.summary.scalar uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on the scope they are created in. Also, passing a tensor or list of tags to a scalar summary op is no longer supported.
# INFO:tensorflow:Starting evaluation at 2017-06-12-13:25:50
# INFO:tensorflow:Restoring parameters from ./iris_model/model.ckpt-8702
# INFO:tensorflow:Finished evaluation at 2017-06-12-13:25:50
# INFO:tensorflow:Saving dict for global step 8702: accuracy = 0.966667, global_step = 8702, loss = 0.183982
# WARNING:tensorflow:Skipping summary for global_step, must be a float or np.float32.
# INFO:tensorflow:Validation (step 8751): loss = 0.183982, accuracy = 0.966667, global_step = 8702
# INFO:tensorflow:Saving checkpoints for 8752 into ./iris_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 44.5175
# INFO:tensorflow:loss = 0.021526, step = 8801 (2.246 sec)
# WARNING:tensorflow:From /Users/ihuangyiran/anaconda2/envs/py3-tf/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:662: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with x is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From /Users/ihuangyiran/anaconda2/envs/py3-tf/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:662: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with y is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From /Users/ihuangyiran/anaconda2/envs/py3-tf/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/estimators/head.py:615: scalar_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.scalar. Note that tf.summary.scalar uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on the scope they are created in. Also, passing a tensor or list of tags to a scalar summary op is no longer supported.
# INFO:tensorflow:Starting evaluation at 2017-06-12-13:25:51
# INFO:tensorflow:Restoring parameters from ./iris_model/model.ckpt-8752
# INFO:tensorflow:Finished evaluation at 2017-06-12-13:25:51
# INFO:tensorflow:Saving dict for global step 8752: accuracy = 0.966667, global_step = 8752, loss = 0.185066
# WARNING:tensorflow:Skipping summary for global_step, must be a float or np.float32.
# INFO:tensorflow:Validation (step 8801): loss = 0.185066, accuracy = 0.966667, global_step = 8752
# INFO:tensorflow:Saving checkpoints for 8802 into ./iris_model/model.ckpt.
# WARNING:tensorflow:From /Users/ihuangyiran/anaconda2/envs/py3-tf/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:662: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with x is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From /Users/ihuangyiran/anaconda2/envs/py3-tf/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:662: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with y is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From /Users/ihuangyiran/anaconda2/envs/py3-tf/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/estimators/head.py:615: scalar_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.scalar. Note that tf.summary.scalar uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on the scope they are created in. Also, passing a tensor or list of tags to a scalar summary op is no longer supported.
# INFO:tensorflow:Starting evaluation at 2017-06-12-13:25:52
# INFO:tensorflow:Restoring parameters from ./iris_model/model.ckpt-8802
# INFO:tensorflow:Finished evaluation at 2017-06-12-13:25:53
# INFO:tensorflow:Saving dict for global step 8802: accuracy = 0.966667, global_step = 8802, loss = 0.18555
# WARNING:tensorflow:Skipping summary for global_step, must be a float or np.float32.
# INFO:tensorflow:Validation (step 8851): loss = 0.18555, accuracy = 0.966667, global_step = 8802
# INFO:tensorflow:Saving checkpoints for 8852 into ./iris_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 40.4948
# INFO:tensorflow:loss = 0.0215336, step = 8901 (2.470 sec)
# WARNING:tensorflow:From /Users/ihuangyiran/anaconda2/envs/py3-tf/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:662: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with x is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From /Users/ihuangyiran/anaconda2/envs/py3-tf/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:662: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with y is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From /Users/ihuangyiran/anaconda2/envs/py3-tf/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/estimators/head.py:615: scalar_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.scalar. Note that tf.summary.scalar uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on the scope they are created in. Also, passing a tensor or list of tags to a scalar summary op is no longer supported.
# INFO:tensorflow:Starting evaluation at 2017-06-12-13:25:53
# INFO:tensorflow:Restoring parameters from ./iris_model/model.ckpt-8852
# INFO:tensorflow:Finished evaluation at 2017-06-12-13:25:54
# INFO:tensorflow:Saving dict for global step 8852: accuracy = 0.966667, global_step = 8852, loss = 0.185991
# WARNING:tensorflow:Skipping summary for global_step, must be a float or np.float32.
# INFO:tensorflow:Validation (step 8901): loss = 0.185991, accuracy = 0.966667, global_step = 8852
# INFO:tensorflow:Saving checkpoints for 8902 into ./iris_model/model.ckpt.
# WARNING:tensorflow:From /Users/ihuangyiran/anaconda2/envs/py3-tf/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:662: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with x is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
# ...
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From /Users/ihuangyiran/anaconda2/envs/py3-tf/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:662: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with y is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From /Users/ihuangyiran/anaconda2/envs/py3-tf/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/estimators/head.py:615: scalar_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.scalar. Note that tf.summary.scalar uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on the scope they are created in. Also, passing a tensor or list of tags to a scalar summary op is no longer supported.
# INFO:tensorflow:Starting evaluation at 2017-06-12-13:25:57
# INFO:tensorflow:Restoring parameters from ./iris_model/model.ckpt-9234
# INFO:tensorflow:Finished evaluation at 2017-06-12-13:25:58
# INFO:tensorflow:Saving dict for global step 9234: accuracy = 0.966667, global_step = 9234, loss = 0.192012
# WARNING:tensorflow:Skipping summary for global_step, must be a float or np.float32.
# INFO:tensorflow:Validation (step 9251): loss = 0.192012, accuracy = 0.966667, global_step = 9234
# INFO:tensorflow:global_step/sec: 65.0304
# INFO:tensorflow:loss = 0.0213307, step = 9301 (1.538 sec)
# INFO:tensorflow:Saving checkpoints for 9352 into ./iris_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 207.791
# INFO:tensorflow:loss = 0.0212269, step = 9401 (0.481 sec)
# WARNING:tensorflow:From /Users/ihuangyiran/anaconda2/envs/py3-tf/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:662: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with x is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From /Users/ihuangyiran/anaconda2/envs/py3-tf/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:662: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with y is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From /Users/ihuangyiran/anaconda2/envs/py3-tf/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/estimators/head.py:615: scalar_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.scalar. Note that tf.summary.scalar uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on the scope they are created in. Also, passing a tensor or list of tags to a scalar summary op is no longer supported.
# INFO:tensorflow:Starting evaluation at 2017-06-12-13:25:58
# INFO:tensorflow:Restoring parameters from ./iris_model/model.ckpt-9352
# INFO:tensorflow:Finished evaluation at 2017-06-12-13:25:59
# INFO:tensorflow:Saving dict for global step 9352: accuracy = 0.966667, global_step = 9352, loss = 0.193945
# WARNING:tensorflow:Skipping summary for global_step, must be a float or np.float32.
# INFO:tensorflow:Validation (step 9401): loss = 0.193945, accuracy = 0.966667, global_step = 9352
# INFO:tensorflow:global_step/sec: 176.1
# INFO:tensorflow:loss = 0.0212174, step = 9501 (0.568 sec)
# INFO:tensorflow:Saving checkpoints for 9502 into ./iris_model/model.ckpt.
# WARNING:tensorflow:From /Users/ihuangyiran/anaconda2/envs/py3-tf/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:662: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with x is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From /Users/ihuangyiran/anaconda2/envs/py3-tf/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:662: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with y is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From /Users/ihuangyiran/anaconda2/envs/py3-tf/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/estimators/head.py:615: scalar_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.scalar. Note that tf.summary.scalar uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on the scope they are created in. Also, passing a tensor or list of tags to a scalar summary op is no longer supported.
# INFO:tensorflow:Starting evaluation at 2017-06-12-13:25:59
# INFO:tensorflow:Restoring parameters from ./iris_model/model.ckpt-9502
# INFO:tensorflow:Finished evaluation at 2017-06-12-13:26:00
# INFO:tensorflow:Saving dict for global step 9502: accuracy = 0.966667, global_step = 9502, loss = 0.195828
# WARNING:tensorflow:Skipping summary for global_step, must be a float or np.float32.
# INFO:tensorflow:Validation (step 9551): loss = 0.195828, accuracy = 0.966667, global_step = 9502
# INFO:tensorflow:global_step/sec: 101.766
# INFO:tensorflow:loss = 0.0211283, step = 9601 (0.982 sec)
# INFO:tensorflow:Saving checkpoints for 9622 into ./iris_model/model.ckpt.
# WARNING:tensorflow:From /Users/ihuangyiran/anaconda2/envs/py3-tf/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:662: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with x is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From /Users/ihuangyiran/anaconda2/envs/py3-tf/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:662: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with y is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From /Users/ihuangyiran/anaconda2/envs/py3-tf/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/estimators/head.py:615: scalar_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.scalar. Note that tf.summary.scalar uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on the scope they are created in. Also, passing a tensor or list of tags to a scalar summary op is no longer supported.
# INFO:tensorflow:Starting evaluation at 2017-06-12-13:26:00
# INFO:tensorflow:Restoring parameters from ./iris_model/model.ckpt-9622
# INFO:tensorflow:Finished evaluation at 2017-06-12-13:26:01
# INFO:tensorflow:Saving dict for global step 9622: accuracy = 0.966667, global_step = 9622, loss = 0.197861
# WARNING:tensorflow:Skipping summary for global_step, must be a float or np.float32.
# INFO:tensorflow:Validation (step 9651): loss = 0.197861, accuracy = 0.966667, global_step = 9622
# INFO:tensorflow:global_step/sec: 99.3358
# INFO:tensorflow:loss = 0.0211116, step = 9701 (1.007 sec)
# INFO:tensorflow:Saving checkpoints for 9714 into ./iris_model/model.ckpt.
# WARNING:tensorflow:From /Users/ihuangyiran/anaconda2/envs/py3-tf/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:662: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with x is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From /Users/ihuangyiran/anaconda2/envs/py3-tf/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:662: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with y is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From /Users/ihuangyiran/anaconda2/envs/py3-tf/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/estimators/head.py:615: scalar_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.scalar. Note that tf.summary.scalar uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on the scope they are created in. Also, passing a tensor or list of tags to a scalar summary op is no longer supported.
# INFO:tensorflow:Starting evaluation at 2017-06-12-13:26:01
# INFO:tensorflow:Restoring parameters from ./iris_model/model.ckpt-9714
# INFO:tensorflow:Finished evaluation at 2017-06-12-13:26:02
# INFO:tensorflow:Saving dict for global step 9714: accuracy = 0.966667, global_step = 9714, loss = 0.199217
# WARNING:tensorflow:Skipping summary for global_step, must be a float or np.float32.
# INFO:tensorflow:Validation (step 9751): loss = 0.199217, accuracy = 0.966667, global_step = 9714
# INFO:tensorflow:global_step/sec: 101.846
# INFO:tensorflow:loss = 0.0210352, step = 9801 (0.982 sec)
# INFO:tensorflow:Saving checkpoints for 9835 into ./iris_model/model.ckpt.
# WARNING:tensorflow:From /Users/ihuangyiran/anaconda2/envs/py3-tf/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:662: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with x is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From /Users/ihuangyiran/anaconda2/envs/py3-tf/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:662: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with y is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From /Users/ihuangyiran/anaconda2/envs/py3-tf/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/estimators/head.py:615: scalar_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.scalar. Note that tf.summary.scalar uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on the scope they are created in. Also, passing a tensor or list of tags to a scalar summary op is no longer supported.
# INFO:tensorflow:Starting evaluation at 2017-06-12-13:26:02
# INFO:tensorflow:Restoring parameters from ./iris_model/model.ckpt-9835
# INFO:tensorflow:Finished evaluation at 2017-06-12-13:26:03
# INFO:tensorflow:Saving dict for global step 9835: accuracy = 0.966667, global_step = 9835, loss = 0.170924
# WARNING:tensorflow:Skipping summary for global_step, must be a float or np.float32.
# INFO:tensorflow:Validation (step 9851): loss = 0.170924, accuracy = 0.966667, global_step = 9835
# INFO:tensorflow:global_step/sec: 103.23
# INFO:tensorflow:loss = 0.0210225, step = 9901 (0.968 sec)
# INFO:tensorflow:Saving checkpoints for 9973 into ./iris_model/model.ckpt.
# INFO:tensorflow:Saving checkpoints for 10000 into ./iris_model/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.0211185.
# WARNING:tensorflow:From /Users/ihuangyiran/anaconda2/envs/py3-tf/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/estimators/head.py:615: scalar_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.scalar. Note that tf.summary.scalar uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on the scope they are created in. Also, passing a tensor or list of tags to a scalar summary op is no longer supported.
# INFO:tensorflow:Starting evaluation at 2017-06-12-13:26:04
# INFO:tensorflow:Restoring parameters from ./iris_model/model.ckpt-10000
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finished evaluation at 2017-06-12-13:26:04
# INFO:tensorflow:Saving dict for global step 10000: accuracy = 0.966667, global_step = 10000, loss = 0.20302
# WARNING:tensorflow:Skipping summary for global_step, must be a float or np.float32.
#
# Test Accuracy:  0.966667
#
# WARNING:tensorflow:From /Users/ihuangyiran/anaconda2/envs/py3-tf/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:335: calling DNNClassifier.predict (from tensorflow.contrib.learn.python.learn.estimators.dnn) with outputs=None is deprecated and will be removed after 2017-03-01.
# Instructions for updating:
# Please switch to predict_classes, or set `outputs` argument.
# INFO:tensorflow:Restoring parameters from ./iris_model/model.ckpt-10000
# New Sample, Class Prediction:    [1, 1]

# %% [markdown]
# By default, if not evaluation metrics are speciied, ValidationMonitor will log both lass and accuracy, but you can customize the list of metrics that will be run every 50 steps. To specify the exact metrics you'd like to run in each evaluation pass, you can add a metrics param to the ValidationMonitor constructor. metrics takes a dict of key/value pairs, where each key is the name you'd like logged for the metric, and the corresponding value is a MetricSpec object.
# <br>
# the MetricSpec constructor accepts four parameters:
# - metric_fn: the function that calculates and returns the value of a metric. This can be a predifined function available in the tf.contrib.metrics modeule, such as tf.contrib.metrics.streaming_precision. Alternatively, you can define your own custom metric function, which must take predictions and labels tensors as arguments. The function must return the value of the metric in one of two formats: a single tensor or a apir of ops(value_op, update_op), where value_op returns the metric value and update_op performs a corresponding operation to update internal model state.
# - prediction_key: The key of the tensor containing the predictions returned by the model. This argument may be omitted if the model returns either a single tensor or a dict with a simgle entry. For a DNNClassifier model, class predictions will be returned in a tensor with the key tf.contrib.learn.PredictionKey.CLASSES
# - label_key: The Key of the tensor containing the labels returned by the model.
# - weights_key: Optional. The key of the tensor(returned by the input_fn) containing weights inputs for the metric_fn.

# %%
validation_metrics = {
    "accuracy":
        tf.contrib.learn.MetricSpec(
            metric_fn = tf.contrib.metrics.streaming_accuracy,
            prediction_key = tf.contrib.learn.PredictionKey.CLASSES),
    "precision":
        tf.contrib.learn.MetricSpec(
            metric_fn = tf.contrib.metrics.streaming_precision,
            prediction_key = tf.contrib.learn.PredictionKey.CLASSES),
    "recall":
        tf.contrib.learn.MetricSpec(
            metric_fn = tf.contrib.metrics.streaming_recall,
            prediction_key = tf.contrib.learn.PredictionKey.CLASSES)
}

# %%
def main():
    # download if file doesn't exist locally
    if not os.path.exists(IRIS_TRAINING):
        raw = urlopen(IRIS_TRAINING_URL).read()
        with open(IRIS_TRAINING, "w") as f:
            f.write(raw.decode('utf-8'))
    if not os.path.exists(IRIS_TEST):
        raw = urlopen(IRIS_TEST_URL).read()
        with open(IRIS_TEST, "w") as f:
            f.write(raw.decode('utf-8'))
    
    # load datasets
    training_set = tf.contrib.learn.datasets.base.load_csv_with_header(
        filename = IRIS_TRAINING,
        target_dtype = np.int,
        features_dtype = np.float32
    )
    test_set = tf.contrib.learn.datasets.base.load_csv_with_header(
        filename = IRIS_TEST,
        target_dtype = np.int,
        features_dtype = np.float32
    )
    
    # Specify that all features have real-value data : 指连续值
    feature_columns = [tf.contrib.layers.real_valued_column("", dimension = 4)]

    
    validation_monitor = tf.contrib.learn.monitors.ValidationMonitor(test_set.data,
                                                                    test_set.target,
                                                                    every_n_steps = 50,
                                                                    metrics = validation_metrics
                                                                    )
    classifier = tf.contrib.learn.DNNClassifier(feature_columns = feature_columns,
                                                hidden_units = [10, 20, 10],
                                                n_classes = 3,
                                                model_dir = "./iris_model",
                                                config = tf.contrib.learn.RunConfig(save_checkpoints_secs = 1)
                                               )
    
    # define the training input
    def get_train_inputs():
        x = tf.constant(training_set.data)
        y = tf.constant(training_set.target)
        return x, y
    
    # fit model
    classifier.fit(input_fn = get_train_inputs,
                   steps = 2000,
                   monitors = [validation_monitor]
                  )
    
    # define the test inputs
    def get_test_inputs():
        x = tf.constant(test_set.data)
        y = tf.constant(test_set.target)
        return x, y
    
    # evaluate accuracy
    accuracy_score = classifier.evaluate(input_fn = get_test_inputs, steps = 1)["accuracy"]
    print("\nTest Accuracy: {0: f}\n".format(accuracy_score))
    
    # classify two new flower samples
    def new_samples():
        return np.array(
        [[6.4, 3.2, 4.5, 1.5],
         [5.8, 3.1, 5.0, 1.7]], dtype = np.float32)
    
    predictions = list(classifier.predict(input_fn = new_samples))
    
    print(
    "New Sample, Class Prediction:    {}\n".format(predictions))

# %%
if __name__ == "__main__":
    main()
# Out:
# WARNING:tensorflow:From /Users/ihuangyiran/anaconda2/envs/py3-tf/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:267: BaseMonitor.__init__ (from tensorflow.contrib.learn.python.learn.monitors) is deprecated and will be removed after 2016-12-05.
# Instructions for updating:
# Monitors are deprecated. Please use tf.train.SessionRunHook.
# INFO:tensorflow:Using config: {'_task_type': None, '_task_id': 0, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x11efa36a0>, '_master': '', '_num_ps_replicas': 0, '_num_worker_replicas': 0, '_environment': 'local', '_is_chief': True, '_evaluation_master': '', '_tf_config': gpu_options {
#   per_process_gpu_memory_fraction: 1
# }
# , '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_secs': 1, '_save_checkpoints_steps': None, '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_model_dir': None}
# WARNING:tensorflow:From /Users/ihuangyiran/anaconda2/envs/py3-tf/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/estimators/head.py:615: scalar_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.scalar. Note that tf.summary.scalar uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on the scope they are created in. Also, passing a tensor or list of tags to a scalar summary op is no longer supported.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from ./iris_model/model.ckpt-10000
# INFO:tensorflow:Saving checkpoints for 10001 into ./iris_model/model.ckpt.
# INFO:tensorflow:loss = 0.0209378, step = 10001
# WARNING:tensorflow:From /Users/ihuangyiran/anaconda2/envs/py3-tf/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:662: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with x is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From /Users/ihuangyiran/anaconda2/envs/py3-tf/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:662: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with y is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From /Users/ihuangyiran/anaconda2/envs/py3-tf/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/estimators/head.py:615: scalar_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.scalar. Note that tf.summary.scalar uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on the scope they are created in. Also, passing a tensor or list of tags to a scalar summary op is no longer supported.
# INFO:tensorflow:Starting evaluation at 2017-06-12-14:01:27
# INFO:tensorflow:Restoring parameters from ./iris_model/model.ckpt-10001
# INFO:tensorflow:Finished evaluation at 2017-06-12-14:01:27
# INFO:tensorflow:Saving dict for global step 10001: accuracy = 0.966667, global_step = 10001, loss = 0.173148, precision = 1.0, recall = 1.0
# WARNING:tensorflow:Skipping summary for global_step, must be a float or np.float32.
# INFO:tensorflow:Validation (step 10001): loss = 0.173148, accuracy = 0.966667, precision = 1.0, recall = 1.0, global_step = 10001
# INFO:tensorflow:Saving checkpoints for 10002 into ./iris_model/model.ckpt.
# WARNING:tensorflow:From /Users/ihuangyiran/anaconda2/envs/py3-tf/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:662: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with x is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From /Users/ihuangyiran/anaconda2/envs/py3-tf/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:662: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with y is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From /Users/ihuangyiran/anaconda2/envs/py3-tf/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/estimators/head.py:615: scalar_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.scalar. Note that tf.summary.scalar uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on the scope they are created in. Also, passing a tensor or list of tags to a scalar summary op is no longer supported.
# INFO:tensorflow:Starting evaluation at 2017-06-12-14:01:29
# INFO:tensorflow:Restoring parameters from ./iris_model/model.ckpt-10002
# INFO:tensorflow:Finished evaluation at 2017-06-12-14:01:29
# INFO:tensorflow:Saving dict for global step 10002: accuracy = 0.966667, global_step = 10002, loss = 0.203517, precision = 1.0, recall = 1.0
# WARNING:tensorflow:Skipping summary for global_step, must be a float or np.float32.
# INFO:tensorflow:Validation (step 10051): loss = 0.203517, accuracy = 0.966667, precision = 1.0, recall = 1.0, global_step = 10002
# INFO:tensorflow:Saving checkpoints for 10052 into ./iris_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.627
# INFO:tensorflow:loss = 0.0209081, step = 10101 (3.163 sec)
# WARNING:tensorflow:From /Users/ihuangyiran/anaconda2/envs/py3-tf/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:662: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with x is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From /Users/ihuangyiran/anaconda2/envs/py3-tf/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:662: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with y is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From /Users/ihuangyiran/anaconda2/envs/py3-tf/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/estimators/head.py:615: scalar_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.scalar. Note that tf.summary.scalar uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on the scope they are created in. Also, passing a tensor or list of tags to a scalar summary op is no longer supported.
# INFO:tensorflow:Starting evaluation at 2017-06-12-14:01:30
# INFO:tensorflow:Restoring parameters from ./iris_model/model.ckpt-10052
# INFO:tensorflow:Finished evaluation at 2017-06-12-14:01:30
# INFO:tensorflow:Saving dict for global step 10052: accuracy = 0.966667, global_step = 10052, loss = 0.204248, precision = 1.0, recall = 1.0
# WARNING:tensorflow:Skipping summary for global_step, must be a float or np.float32.
# INFO:tensorflow:Validation (step 10101): loss = 0.204248, accuracy = 0.966667, precision = 1.0, recall = 1.0, global_step = 10052
# INFO:tensorflow:Saving checkpoints for 10102 into ./iris_model/model.ckpt.
# WARNING:tensorflow:From /Users/ihuangyiran/anaconda2/envs/py3-tf/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:662: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with x is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From /Users/ihuangyiran/anaconda2/envs/py3-tf/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:662: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with y is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From /Users/ihuangyiran/anaconda2/envs/py3-tf/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/estimators/head.py:615: scalar_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.scalar. Note that tf.summary.scalar uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on the scope they are created in. Also, passing a tensor or list of tags to a scalar summary op is no longer supported.
# INFO:tensorflow:Starting evaluation at 2017-06-12-14:01:31
# INFO:tensorflow:Restoring parameters from ./iris_model/model.ckpt-10102
# INFO:tensorflow:Finished evaluation at 2017-06-12-14:01:31
# INFO:tensorflow:Saving dict for global step 10102: accuracy = 0.966667, global_step = 10102, loss = 0.204284, precision = 1.0, recall = 1.0
# WARNING:tensorflow:Skipping summary for global_step, must be a float or np.float32.
# INFO:tensorflow:Validation (step 10151): loss = 0.204284, accuracy = 0.966667, precision = 1.0, recall = 1.0, global_step = 10102
# INFO:tensorflow:Saving checkpoints for 10152 into ./iris_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 41.8003
# INFO:tensorflow:loss = 0.020831, step = 10201 (2.392 sec)
# WARNING:tensorflow:From /Users/ihuangyiran/anaconda2/envs/py3-tf/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:662: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with x is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From /Users/ihuangyiran/anaconda2/envs/py3-tf/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:662: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with y is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From /Users/ihuangyiran/anaconda2/envs/py3-tf/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/estimators/head.py:615: scalar_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.scalar. Note that tf.summary.scalar uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on the scope they are created in. Also, passing a tensor or list of tags to a scalar summary op is no longer supported.
# INFO:tensorflow:Starting evaluation at 2017-06-12-14:01:32
# INFO:tensorflow:Restoring parameters from ./iris_model/model.ckpt-10152
# INFO:tensorflow:Finished evaluation at 2017-06-12-14:01:32
# INFO:tensorflow:Saving dict for global step 10152: accuracy = 0.966667, global_step = 10152, loss = 0.205221, precision = 1.0, recall = 1.0
# WARNING:tensorflow:Skipping summary for global_step, must be a float or np.float32.
# INFO:tensorflow:Validation (step 10201): loss = 0.205221, accuracy = 0.966667, precision = 1.0, recall = 1.0, global_step = 10152
# INFO:tensorflow:Saving checkpoints for 10202 into ./iris_model/model.ckpt.
# WARNING:tensorflow:From /Users/ihuangyiran/anaconda2/envs/py3-tf/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:662: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with x is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From /Users/ihuangyiran/anaconda2/envs/py3-tf/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:662: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with y is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From /Users/ihuangyiran/anaconda2/envs/py3-tf/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/estimators/head.py:615: scalar_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.scalar. Note that tf.summary.scalar uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on the scope they are created in. Also, passing a tensor or list of tags to a scalar summary op is no longer supported.
# INFO:tensorflow:Starting evaluation at 2017-06-12-14:01:33
# INFO:tensorflow:Restoring parameters from ./iris_model/model.ckpt-10202
# INFO:tensorflow:Finished evaluation at 2017-06-12-14:01:34
# INFO:tensorflow:Saving dict for global step 10202: accuracy = 0.966667, global_step = 10202, loss = 0.206211, precision = 1.0, recall = 1.0
# WARNING:tensorflow:Skipping summary for global_step, must be a float or np.float32.
# INFO:tensorflow:Validation (step 10251): loss = 0.206211, accuracy = 0.966667, precision = 1.0, recall = 1.0, global_step = 10202
# INFO:tensorflow:Saving checkpoints for 10252 into ./iris_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 44.0685
# INFO:tensorflow:loss = 0.0207918, step = 10301 (2.269 sec)
# WARNING:tensorflow:From /Users/ihuangyiran/anaconda2/envs/py3-tf/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:662: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with x is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From /Users/ihuangyiran/anaconda2/envs/py3-tf/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:662: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with y is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From /Users/ihuangyiran/anaconda2/envs/py3-tf/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/estimators/head.py:615: scalar_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.scalar. Note that tf.summary.scalar uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on the scope they are created in. Also, passing a tensor or list of tags to a scalar summary op is no longer supported.
# INFO:tensorflow:Starting evaluation at 2017-06-12-14:01:34
# INFO:tensorflow:Restoring parameters from ./iris_model/model.ckpt-10252
# INFO:tensorflow:Finished evaluation at 2017-06-12-14:01:35
# INFO:tensorflow:Saving dict for global step 10252: accuracy = 0.966667, global_step = 10252, loss = 0.20644, precision = 1.0, recall = 1.0
# WARNING:tensorflow:Skipping summary for global_step, must be a float or np.float32.
# INFO:tensorflow:Validation (step 10301): loss = 0.20644, accuracy = 0.966667, precision = 1.0, recall = 1.0, global_step = 10252
# INFO:tensorflow:Saving checkpoints for 10302 into ./iris_model/model.ckpt.
# WARNING:tensorflow:From /Users/ihuangyiran/anaconda2/envs/py3-tf/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:662: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with x is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From /Users/ihuangyiran/anaconda2/envs/py3-tf/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:662: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with y is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From /Users/ihuangyiran/anaconda2/envs/py3-tf/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/estimators/head.py:615: scalar_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.scalar. Note that tf.summary.scalar uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on the scope they are created in. Also, passing a tensor or list of tags to a scalar summary op is no longer supported.
# INFO:tensorflow:Starting evaluation at 2017-06-12-14:01:36
# INFO:tensorflow:Restoring parameters from ./iris_model/model.ckpt-10302
# INFO:tensorflow:Finished evaluation at 2017-06-12-14:01:36
# INFO:tensorflow:Saving dict for global step 10302: accuracy = 0.966667, global_step = 10302, loss = 0.207625, precision = 1.0, recall = 1.0
# WARNING:tensorflow:Skipping summary for global_step, must be a float or np.float32.
# INFO:tensorflow:Validation (step 10351): loss = 0.207625, accuracy = 0.966667, precision = 1.0, recall = 1.0, global_step = 10302
# INFO:tensorflow:Saving checkpoints for 10352 into ./iris_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 42.1895
# INFO:tensorflow:loss = 0.0207869, step = 10401 (2.370 sec)
# WARNING:tensorflow:From /Users/ihuangyiran/anaconda2/envs/py3-tf/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:662: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with x is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From /Users/ihuangyiran/anaconda2/envs/py3-tf/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:662: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with y is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From /Users/ihuangyiran/anaconda2/envs/py3-tf/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/estimators/head.py:615: scalar_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.scalar. Note that tf.summary.scalar uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on the scope they are created in. Also, passing a tensor or list of tags to a scalar summary op is no longer supported.
# INFO:tensorflow:Starting evaluation at 2017-06-12-14:01:37
# INFO:tensorflow:Restoring parameters from ./iris_model/model.ckpt-10352
# INFO:tensorflow:Finished evaluation at 2017-06-12-14:01:37
# INFO:tensorflow:Saving dict for global step 10352: accuracy = 0.966667, global_step = 10352, loss = 0.208003, precision = 1.0, recall = 1.0
# WARNING:tensorflow:Skipping summary for global_step, must be a float or np.float32.
# INFO:tensorflow:Validation (step 10401): loss = 0.208003, accuracy = 0.966667, precision = 1.0, recall = 1.0, global_step = 10352
# INFO:tensorflow:Saving checkpoints for 10402 into ./iris_model/model.ckpt.
# WARNING:tensorflow:From /Users/ihuangyiran/anaconda2/envs/py3-tf/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:662: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with x is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From /Users/ihuangyiran/anaconda2/envs/py3-tf/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:662: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with y is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From /Users/ihuangyiran/anaconda2/envs/py3-tf/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/estimators/head.py:615: scalar_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.scalar. Note that tf.summary.scalar uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on the scope they are created in. Also, passing a tensor or list of tags to a scalar summary op is no longer supported.
# INFO:tensorflow:Starting evaluation at 2017-06-12-14:01:38
# INFO:tensorflow:Restoring parameters from ./iris_model/model.ckpt-10402
# INFO:tensorflow:Finished evaluation at 2017-06-12-14:01:39
# INFO:tensorflow:Saving dict for global step 10402: accuracy = 0.966667, global_step = 10402, loss = 0.208469, precision = 1.0, recall = 1.0
# WARNING:tensorflow:Skipping summary for global_step, must be a float or np.float32.
# INFO:tensorflow:Validation (step 10451): loss = 0.208469, accuracy = 0.966667, precision = 1.0, recall = 1.0, global_step = 10402
# INFO:tensorflow:Saving checkpoints for 10452 into ./iris_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 33.9403
# INFO:tensorflow:loss = 0.0207385, step = 10501 (2.947 sec)
# WARNING:tensorflow:From /Users/ihuangyiran/anaconda2/envs/py3-tf/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:662: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with x is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From /Users/ihuangyiran/anaconda2/envs/py3-tf/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:662: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with y is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From /Users/ihuangyiran/anaconda2/envs/py3-tf/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/estimators/head.py:615: scalar_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.scalar. Note that tf.summary.scalar uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on the scope they are created in. Also, passing a tensor or list of tags to a scalar summary op is no longer supported.
# INFO:tensorflow:Starting evaluation at 2017-06-12-14:01:40
# INFO:tensorflow:Restoring parameters from ./iris_model/model.ckpt-10452
# INFO:tensorflow:Finished evaluation at 2017-06-12-14:01:40
# INFO:tensorflow:Saving dict for global step 10452: accuracy = 0.966667, global_step = 10452, loss = 0.209156, precision = 1.0, recall = 1.0
# WARNING:tensorflow:Skipping summary for global_step, must be a float or np.float32.
# INFO:tensorflow:Validation (step 10501): loss = 0.209156, accuracy = 0.966667, precision = 1.0, recall = 1.0, global_step = 10452
# INFO:tensorflow:Saving checkpoints for 10502 into ./iris_model/model.ckpt.
# WARNING:tensorflow:From /Users/ihuangyiran/anaconda2/envs/py3-tf/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:662: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with x is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From /Users/ihuangyiran/anaconda2/envs/py3-tf/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:662: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with y is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From /Users/ihuangyiran/anaconda2/envs/py3-tf/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/estimators/head.py:615: scalar_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.scalar. Note that tf.summary.scalar uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on the scope they are created in. Also, passing a tensor or list of tags to a scalar summary op is no longer supported.
# INFO:tensorflow:Starting evaluation at 2017-06-12-14:01:41
# INFO:tensorflow:Restoring parameters from ./iris_model/model.ckpt-10502
# INFO:tensorflow:Finished evaluation at 2017-06-12-14:01:42
# INFO:tensorflow:Saving dict for global step 10502: accuracy = 0.966667, global_step = 10502, loss = 0.209841, precision = 1.0, recall = 1.0
# WARNING:tensorflow:Skipping summary for global_step, must be a float or np.float32.
# INFO:tensorflow:Validation (step 10551): loss = 0.209841, accuracy = 0.966667, precision = 1.0, recall = 1.0, global_step = 10502
# INFO:tensorflow:Saving checkpoints for 10552 into ./iris_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 35.9959
# INFO:tensorflow:loss = 0.0207283, step = 10601 (2.780 sec)
# WARNING:tensorflow:From /Users/ihuangyiran/anaconda2/envs/py3-tf/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:662: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with x is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From /Users/ihuangyiran/anaconda2/envs/py3-tf/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:662: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with y is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From /Users/ihuangyiran/anaconda2/envs/py3-tf/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/estimators/head.py:615: scalar_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.scalar. Note that tf.summary.scalar uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on the scope they are created in. Also, passing a tensor or list of tags to a scalar summary op is no longer supported.
# INFO:tensorflow:Starting evaluation at 2017-06-12-14:01:42
# INFO:tensorflow:Restoring parameters from ./iris_model/model.ckpt-10552
# INFO:tensorflow:Finished evaluation at 2017-06-12-14:01:43
# INFO:tensorflow:Saving dict for global step 10552: accuracy = 0.966667, global_step = 10552, loss = 0.210552, precision = 1.0, recall = 1.0
# WARNING:tensorflow:Skipping summary for global_step, must be a float or np.float32.
# INFO:tensorflow:Validation (step 10601): loss = 0.210552, accuracy = 0.966667, precision = 1.0, recall = 1.0, global_step = 10552
# INFO:tensorflow:Saving checkpoints for 10602 into ./iris_model/model.ckpt.
# WARNING:tensorflow:From /Users/ihuangyiran/anaconda2/envs/py3-tf/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:662: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with x is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From /Users/ihuangyiran/anaconda2/envs/py3-tf/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:662: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with y is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From /Users/ihuangyiran/anaconda2/envs/py3-tf/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/estimators/head.py:615: scalar_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.scalar. Note that tf.summary.scalar uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on the scope they are created in. Also, passing a tensor or list of tags to a scalar summary op is no longer supported.
# INFO:tensorflow:Starting evaluation at 2017-06-12-14:01:44
# INFO:tensorflow:Restoring parameters from ./iris_model/model.ckpt-10602
# INFO:tensorflow:Finished evaluation at 2017-06-12-14:01:44
# INFO:tensorflow:Saving dict for global step 10602: accuracy = 0.966667, global_step = 10602, loss = 0.211346, precision = 1.0, recall = 1.0
# WARNING:tensorflow:Skipping summary for global_step, must be a float or np.float32.
# INFO:tensorflow:Validation (step 10651): loss = 0.211346, accuracy = 0.966667, precision = 1.0, recall = 1.0, global_step = 10602
# INFO:tensorflow:Saving checkpoints for 10652 into ./iris_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 43.5862
# INFO:tensorflow:loss = 0.0206464, step = 10701 (2.293 sec)
# WARNING:tensorflow:From /Users/ihuangyiran/anaconda2/envs/py3-tf/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:662: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with x is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From /Users/ihuangyiran/anaconda2/envs/py3-tf/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:662: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with y is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From /Users/ihuangyiran/anaconda2/envs/py3-tf/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/estimators/head.py:615: scalar_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.scalar. Note that tf.summary.scalar uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on the scope they are created in. Also, passing a tensor or list of tags to a scalar summary op is no longer supported.
# INFO:tensorflow:Starting evaluation at 2017-06-12-14:01:45
# INFO:tensorflow:Restoring parameters from ./iris_model/model.ckpt-10652
# INFO:tensorflow:Finished evaluation at 2017-06-12-14:01:45
# INFO:tensorflow:Saving dict for global step 10652: accuracy = 0.966667, global_step = 10652, loss = 0.212175, precision = 1.0, recall = 1.0
# WARNING:tensorflow:Skipping summary for global_step, must be a float or np.float32.
# INFO:tensorflow:Validation (step 10701): loss = 0.212175, accuracy = 0.966667, precision = 1.0, recall = 1.0, global_step = 10652
# INFO:tensorflow:Saving checkpoints for 10702 into ./iris_model/model.ckpt.
# WARNING:tensorflow:From /Users/ihuangyiran/anaconda2/envs/py3-tf/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:662: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with x is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From /Users/ihuangyiran/anaconda2/envs/py3-tf/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:662: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with y is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From /Users/ihuangyiran/anaconda2/envs/py3-tf/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/estimators/head.py:615: scalar_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.scalar. Note that tf.summary.scalar uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on the scope they are created in. Also, passing a tensor or list of tags to a scalar summary op is no longer supported.
# INFO:tensorflow:Starting evaluation at 2017-06-12-14:01:46
# INFO:tensorflow:Restoring parameters from ./iris_model/model.ckpt-10702
# INFO:tensorflow:Finished evaluation at 2017-06-12-14:01:46
# INFO:tensorflow:Saving dict for global step 10702: accuracy = 0.966667, global_step = 10702, loss = 0.21318, precision = 1.0, recall = 1.0
# WARNING:tensorflow:Skipping summary for global_step, must be a float or np.float32.
# INFO:tensorflow:Validation (step 10751): loss = 0.21318, accuracy = 0.966667, precision = 1.0, recall = 1.0, global_step = 10702
# INFO:tensorflow:Saving checkpoints for 10752 into ./iris_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 45.0287
# INFO:tensorflow:loss = 0.0206051, step = 10801 (2.220 sec)
# WARNING:tensorflow:From /Users/ihuangyiran/anaconda2/envs/py3-tf/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:662: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with x is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From /Users/ihuangyiran/anaconda2/envs/py3-tf/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:662: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with y is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From /Users/ihuangyiran/anaconda2/envs/py3-tf/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/estimators/head.py:615: scalar_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.scalar. Note that tf.summary.scalar uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on the scope they are created in. Also, passing a tensor or list of tags to a scalar summary op is no longer supported.
# INFO:tensorflow:Starting evaluation at 2017-06-12-14:01:47
# INFO:tensorflow:Restoring parameters from ./iris_model/model.ckpt-10752
# INFO:tensorflow:Finished evaluation at 2017-06-12-14:01:47
# INFO:tensorflow:Saving dict for global step 10752: accuracy = 0.966667, global_step = 10752, loss = 0.213575, precision = 1.0, recall = 1.0
# WARNING:tensorflow:Skipping summary for global_step, must be a float or np.float32.
# INFO:tensorflow:Validation (step 10801): loss = 0.213575, accuracy = 0.966667, precision = 1.0, recall = 1.0, global_step = 10752
# INFO:tensorflow:Saving checkpoints for 10802 into ./iris_model/model.ckpt.
# WARNING:tensorflow:From /Users/ihuangyiran/anaconda2/envs/py3-tf/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:662: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with x is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From /Users/ihuangyiran/anaconda2/envs/py3-tf/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:662: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with y is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From /Users/ihuangyiran/anaconda2/envs/py3-tf/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/estimators/head.py:615: scalar_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.scalar. Note that tf.summary.scalar uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on the scope they are created in. Also, passing a tensor or list of tags to a scalar summary op is no longer supported.
# INFO:tensorflow:Starting evaluation at 2017-06-12-14:01:48
# INFO:tensorflow:Restoring parameters from ./iris_model/model.ckpt-10802
# INFO:tensorflow:Finished evaluation at 2017-06-12-14:01:48
# INFO:tensorflow:Saving dict for global step 10802: accuracy = 0.966667, global_step = 10802, loss = 0.214482, precision = 1.0, recall = 1.0
# WARNING:tensorflow:Skipping summary for global_step, must be a float or np.float32.
# INFO:tensorflow:Validation (step 10851): loss = 0.214482, accuracy = 0.966667, precision = 1.0, recall = 1.0, global_step = 10802
# INFO:tensorflow:Saving checkpoints for 10852 into ./iris_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 44.8535
# INFO:tensorflow:loss = 0.0206062, step = 10901 (2.229 sec)
# WARNING:tensorflow:From /Users/ihuangyiran/anaconda2/envs/py3-tf/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:662: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with x is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From /Users/ihuangyiran/anaconda2/envs/py3-tf/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:662: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with y is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From /Users/ihuangyiran/anaconda2/envs/py3-tf/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/estimators/head.py:615: scalar_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# ...
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From /Users/ihuangyiran/anaconda2/envs/py3-tf/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:662: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with y is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From /Users/ihuangyiran/anaconda2/envs/py3-tf/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/estimators/head.py:615: scalar_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.scalar. Note that tf.summary.scalar uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on the scope they are created in. Also, passing a tensor or list of tags to a scalar summary op is no longer supported.
# INFO:tensorflow:Starting evaluation at 2017-06-12-14:02:09
# INFO:tensorflow:Restoring parameters from ./iris_model/model.ckpt-11652
# INFO:tensorflow:Finished evaluation at 2017-06-12-14:02:10
# INFO:tensorflow:Saving dict for global step 11652: accuracy = 0.966667, global_step = 11652, loss = 0.225495, precision = 1.0, recall = 1.0
# WARNING:tensorflow:Skipping summary for global_step, must be a float or np.float32.
# INFO:tensorflow:Validation (step 11701): loss = 0.225495, accuracy = 0.966667, precision = 1.0, recall = 1.0, global_step = 11652
# INFO:tensorflow:Saving checkpoints for 11702 into ./iris_model/model.ckpt.
# WARNING:tensorflow:From /Users/ihuangyiran/anaconda2/envs/py3-tf/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:662: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with x is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From /Users/ihuangyiran/anaconda2/envs/py3-tf/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:662: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with y is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From /Users/ihuangyiran/anaconda2/envs/py3-tf/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/estimators/head.py:615: scalar_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.scalar. Note that tf.summary.scalar uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on the scope they are created in. Also, passing a tensor or list of tags to a scalar summary op is no longer supported.
# INFO:tensorflow:Starting evaluation at 2017-06-12-14:02:11
# INFO:tensorflow:Restoring parameters from ./iris_model/model.ckpt-11702
# INFO:tensorflow:Finished evaluation at 2017-06-12-14:02:11
# INFO:tensorflow:Saving dict for global step 11702: accuracy = 0.966667, global_step = 11702, loss = 0.226123, precision = 1.0, recall = 1.0
# WARNING:tensorflow:Skipping summary for global_step, must be a float or np.float32.
# INFO:tensorflow:Validation (step 11751): loss = 0.226123, accuracy = 0.966667, precision = 1.0, recall = 1.0, global_step = 11702
# INFO:tensorflow:Saving checkpoints for 11752 into ./iris_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.0716
# INFO:tensorflow:loss = 0.0202841, step = 11801 (3.217 sec)
# WARNING:tensorflow:From /Users/ihuangyiran/anaconda2/envs/py3-tf/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:662: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with x is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From /Users/ihuangyiran/anaconda2/envs/py3-tf/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:662: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with y is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From /Users/ihuangyiran/anaconda2/envs/py3-tf/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/estimators/head.py:615: scalar_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.scalar. Note that tf.summary.scalar uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on the scope they are created in. Also, passing a tensor or list of tags to a scalar summary op is no longer supported.
# INFO:tensorflow:Starting evaluation at 2017-06-12-14:02:12
# INFO:tensorflow:Restoring parameters from ./iris_model/model.ckpt-11752
# INFO:tensorflow:Finished evaluation at 2017-06-12-14:02:13
# INFO:tensorflow:Saving dict for global step 11752: accuracy = 0.966667, global_step = 11752, loss = 0.22699, precision = 1.0, recall = 1.0
# WARNING:tensorflow:Skipping summary for global_step, must be a float or np.float32.
# INFO:tensorflow:Validation (step 11801): loss = 0.22699, accuracy = 0.966667, precision = 1.0, recall = 1.0, global_step = 11752
# INFO:tensorflow:Saving checkpoints for 11802 into ./iris_model/model.ckpt.
# WARNING:tensorflow:From /Users/ihuangyiran/anaconda2/envs/py3-tf/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:662: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with x is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From /Users/ihuangyiran/anaconda2/envs/py3-tf/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:662: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with y is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From /Users/ihuangyiran/anaconda2/envs/py3-tf/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/estimators/head.py:615: scalar_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.scalar. Note that tf.summary.scalar uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on the scope they are created in. Also, passing a tensor or list of tags to a scalar summary op is no longer supported.
# INFO:tensorflow:Starting evaluation at 2017-06-12-14:02:13
# INFO:tensorflow:Restoring parameters from ./iris_model/model.ckpt-11802
# INFO:tensorflow:Finished evaluation at 2017-06-12-14:02:14
# INFO:tensorflow:Saving dict for global step 11802: accuracy = 0.966667, global_step = 11802, loss = 0.226983, precision = 1.0, recall = 1.0
# WARNING:tensorflow:Skipping summary for global_step, must be a float or np.float32.
# INFO:tensorflow:Validation (step 11851): loss = 0.226983, accuracy = 0.966667, precision = 1.0, recall = 1.0, global_step = 11802
# INFO:tensorflow:Saving checkpoints for 11852 into ./iris_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 41.8738
# INFO:tensorflow:loss = 0.0203267, step = 11901 (2.388 sec)
# WARNING:tensorflow:From /Users/ihuangyiran/anaconda2/envs/py3-tf/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:662: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with x is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From /Users/ihuangyiran/anaconda2/envs/py3-tf/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:662: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with y is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From /Users/ihuangyiran/anaconda2/envs/py3-tf/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/estimators/head.py:615: scalar_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.scalar. Note that tf.summary.scalar uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on the scope they are created in. Also, passing a tensor or list of tags to a scalar summary op is no longer supported.
# INFO:tensorflow:Starting evaluation at 2017-06-12-14:02:15
# INFO:tensorflow:Restoring parameters from ./iris_model/model.ckpt-11852
# INFO:tensorflow:Finished evaluation at 2017-06-12-14:02:15
# INFO:tensorflow:Saving dict for global step 11852: accuracy = 0.966667, global_step = 11852, loss = 0.227762, precision = 1.0, recall = 1.0
# WARNING:tensorflow:Skipping summary for global_step, must be a float or np.float32.
# INFO:tensorflow:Validation (step 11901): loss = 0.227762, accuracy = 0.966667, precision = 1.0, recall = 1.0, global_step = 11852
# INFO:tensorflow:Saving checkpoints for 11902 into ./iris_model/model.ckpt.
# WARNING:tensorflow:From /Users/ihuangyiran/anaconda2/envs/py3-tf/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:662: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with x is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From /Users/ihuangyiran/anaconda2/envs/py3-tf/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:662: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with y is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From /Users/ihuangyiran/anaconda2/envs/py3-tf/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/estimators/head.py:615: scalar_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.scalar. Note that tf.summary.scalar uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on the scope they are created in. Also, passing a tensor or list of tags to a scalar summary op is no longer supported.
# INFO:tensorflow:Starting evaluation at 2017-06-12-14:02:16
# INFO:tensorflow:Restoring parameters from ./iris_model/model.ckpt-11902
# INFO:tensorflow:Finished evaluation at 2017-06-12-14:02:16
# INFO:tensorflow:Saving dict for global step 11902: accuracy = 0.966667, global_step = 11902, loss = 0.228627, precision = 1.0, recall = 1.0
# WARNING:tensorflow:Skipping summary for global_step, must be a float or np.float32.
# INFO:tensorflow:Validation (step 11951): loss = 0.228627, accuracy = 0.966667, precision = 1.0, recall = 1.0, global_step = 11902
# INFO:tensorflow:Saving checkpoints for 11952 into ./iris_model/model.ckpt.
# INFO:tensorflow:Saving checkpoints for 12000 into ./iris_model/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.0205119.
# WARNING:tensorflow:From /Users/ihuangyiran/anaconda2/envs/py3-tf/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/estimators/head.py:615: scalar_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.scalar. Note that tf.summary.scalar uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on the scope they are created in. Also, passing a tensor or list of tags to a scalar summary op is no longer supported.
# INFO:tensorflow:Starting evaluation at 2017-06-12-14:02:17
# INFO:tensorflow:Restoring parameters from ./iris_model/model.ckpt-12000
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finished evaluation at 2017-06-12-14:02:17
# INFO:tensorflow:Saving dict for global step 12000: accuracy = 0.966667, global_step = 12000, loss = 0.23014
# WARNING:tensorflow:Skipping summary for global_step, must be a float or np.float32.
#
# Test Accuracy:  0.966667
#
# WARNING:tensorflow:From /Users/ihuangyiran/anaconda2/envs/py3-tf/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:335: calling DNNClassifier.predict (from tensorflow.contrib.learn.python.learn.estimators.dnn) with outputs=None is deprecated and will be removed after 2017-03-01.
# Instructions for updating:
# Please switch to predict_classes, or set `outputs` argument.
# INFO:tensorflow:Restoring parameters from ./iris_model/model.ckpt-12000
# New Sample, Class Prediction:    [1, 1]

# %% [markdown]
# In addition to logging eval metrics, ValidationMonitor make it easy to implement early stopping when specified conditions are met, via three params:
# - early_stopping_metric: Metric that triggers early stopping(e.g. loss) under conditons specified in early_stopping_rounds and early_stopping_metric_minimize. Default is "loss:
# - early_stopping_metric_minimize: True if desired model behavior is to minimize the value of early_stopping_metric; False if desired model behavior is to maiximize the value of early_stopping_metric. Default is True
# - early_stopping_rounds: Sets a number of steps during whichif the realy_stopping_metric does not decrease or increase, training will be stoped. Default to None, which means early stopping will never occur.

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-9834008089b0> in <module>()
# ----> 1 validation_monitor = tf.contrib.learn.monitors.ValidationMonitor(test_set.data,
#       2                                                                 test_set.target,
#       3                                                                 every_n_steps = 50,
#       4                                                                 metrics = validation_metrics,
#       5                                                                 early_stopping_metric = "loss",
#
# NameError: name 'test_set' is not defined

# %%
def main():
    # download if file doesn't exist locally
    if not os.path.exists(IRIS_TRAINING):
        raw = urlopen(IRIS_TRAINING_URL).read()
        with open(IRIS_TRAINING, "w") as f:
            f.write(raw.decode('utf-8'))
    if not os.path.exists(IRIS_TEST):
        raw = urlopen(IRIS_TEST_URL).read()
        with open(IRIS_TEST, "w") as f:
            f.write(raw.decode('utf-8'))
    
    # load datasets
    training_set = tf.contrib.learn.datasets.base.load_csv_with_header(
        filename = IRIS_TRAINING,
        target_dtype = np.int,
        features_dtype = np.float32
    )
    test_set = tf.contrib.learn.datasets.base.load_csv_with_header(
        filename = IRIS_TEST,
        target_dtype = np.int,
        features_dtype = np.float32
    )
    
    # Specify that all features have real-value data : 指连续值
    feature_columns = [tf.contrib.layers.real_valued_column("", dimension = 4)]

    
    validation_monitor = tf.contrib.learn.monitors.ValidationMonitor(test_set.data,
                                                                    test_set.target,
                                                                    every_n_steps = 50,
                                                                    metrics = validation_metrics,
                                                                    early_stopping_metric = "loss",
                                                                    early_stopping_metric_minimize = True,
                                                                    early_stopping_rounds = 200
                                                                    )
    classifier = tf.contrib.learn.DNNClassifier(feature_columns = feature_columns,
                                                hidden_units = [10, 20, 10],
                                                n_classes = 3,
                                                model_dir = "./iris_model",
                                                config = tf.contrib.learn.RunConfig(save_checkpoints_secs = 1)
                                               )
    
    # define the training input
    def get_train_inputs():
        x = tf.constant(training_set.data)
        y = tf.constant(training_set.target)
        return x, y
    
    # fit model
    classifier.fit(input_fn = get_train_inputs,
                   steps = 2000,
                   monitors = [validation_monitor]
                  )
    
    # define the test inputs
    def get_test_inputs():
        x = tf.constant(test_set.data)
        y = tf.constant(test_set.target)
        return x, y
    
    # evaluate accuracy
    accuracy_score = classifier.evaluate(input_fn = get_test_inputs, steps = 1)["accuracy"]
    print("\nTest Accuracy: {0: f}\n".format(accuracy_score))
    
    # classify two new flower samples
    def new_samples():
        return np.array(
        [[6.4, 3.2, 4.5, 1.5],
         [5.8, 3.1, 5.0, 1.7]], dtype = np.float32)
    
    predictions = list(classifier.predict(input_fn = new_samples))
    
    print(
    "New Sample, Class Prediction:    {}\n".format(predictions))

# %%
if __name__ == "__main__":
    main()
# Out:
# WARNING:tensorflow:From /Users/ihuangyiran/anaconda2/envs/py3-tf/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:267: BaseMonitor.__init__ (from tensorflow.contrib.learn.python.learn.monitors) is deprecated and will be removed after 2016-12-05.
# Instructions for updating:
# Monitors are deprecated. Please use tf.train.SessionRunHook.
# INFO:tensorflow:Using config: {'_task_type': None, '_task_id': 0, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x11f16cfd0>, '_master': '', '_num_ps_replicas': 0, '_num_worker_replicas': 0, '_environment': 'local', '_is_chief': True, '_evaluation_master': '', '_tf_config': gpu_options {
#   per_process_gpu_memory_fraction: 1
# }
# , '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_secs': 1, '_save_checkpoints_steps': None, '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_model_dir': None}
# WARNING:tensorflow:From /Users/ihuangyiran/anaconda2/envs/py3-tf/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/estimators/head.py:615: scalar_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.scalar. Note that tf.summary.scalar uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on the scope they are created in. Also, passing a tensor or list of tags to a scalar summary op is no longer supported.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Saving checkpoints for 1 into ./iris_model/model.ckpt.
# INFO:tensorflow:loss = 1.21539, step = 1
# WARNING:tensorflow:From /Users/ihuangyiran/anaconda2/envs/py3-tf/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:662: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with x is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From /Users/ihuangyiran/anaconda2/envs/py3-tf/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:662: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with y is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From /Users/ihuangyiran/anaconda2/envs/py3-tf/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/estimators/head.py:615: scalar_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.scalar. Note that tf.summary.scalar uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on the scope they are created in. Also, passing a tensor or list of tags to a scalar summary op is no longer supported.
# INFO:tensorflow:Starting evaluation at 2017-06-12-14:21:06
# INFO:tensorflow:Restoring parameters from ./iris_model/model.ckpt-1
# INFO:tensorflow:Finished evaluation at 2017-06-12-14:21:06
# INFO:tensorflow:Saving dict for global step 1: accuracy = 0.666667, global_step = 1, loss = 1.01802, precision = 0.733333, recall = 1.0
# WARNING:tensorflow:Skipping summary for global_step, must be a float or np.float32.
# INFO:tensorflow:Validation (step 50): loss = 1.01802, accuracy = 0.666667, precision = 0.733333, recall = 1.0, global_step = 1
# INFO:tensorflow:Saving checkpoints for 51 into ./iris_model/model.ckpt.
# WARNING:tensorflow:From /Users/ihuangyiran/anaconda2/envs/py3-tf/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:662: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with x is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From /Users/ihuangyiran/anaconda2/envs/py3-tf/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:662: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with y is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From /Users/ihuangyiran/anaconda2/envs/py3-tf/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/estimators/head.py:615: scalar_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.scalar. Note that tf.summary.scalar uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on the scope they are created in. Also, passing a tensor or list of tags to a scalar summary op is no longer supported.
# INFO:tensorflow:Starting evaluation at 2017-06-12-14:21:07
# INFO:tensorflow:Restoring parameters from ./iris_model/model.ckpt-51
# INFO:tensorflow:Finished evaluation at 2017-06-12-14:21:08
# INFO:tensorflow:Saving dict for global step 51: accuracy = 0.933333, global_step = 51, loss = 0.24078, precision = 1.0, recall = 1.0
# WARNING:tensorflow:Skipping summary for global_step, must be a float or np.float32.
# INFO:tensorflow:Validation (step 100): loss = 0.24078, accuracy = 0.933333, precision = 1.0, recall = 1.0, global_step = 51
# INFO:tensorflow:Saving checkpoints for 101 into ./iris_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 35.8677
# INFO:tensorflow:loss = 0.101007, step = 101 (2.789 sec)
# WARNING:tensorflow:From /Users/ihuangyiran/anaconda2/envs/py3-tf/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:662: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with x is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From /Users/ihuangyiran/anaconda2/envs/py3-tf/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:662: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with y is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From /Users/ihuangyiran/anaconda2/envs/py3-tf/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/estimators/head.py:615: scalar_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.scalar. Note that tf.summary.scalar uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on the scope they are created in. Also, passing a tensor or list of tags to a scalar summary op is no longer supported.
# INFO:tensorflow:Starting evaluation at 2017-06-12-14:21:09
# INFO:tensorflow:Restoring parameters from ./iris_model/model.ckpt-101
# INFO:tensorflow:Finished evaluation at 2017-06-12-14:21:09
# INFO:tensorflow:Saving dict for global step 101: accuracy = 0.966667, global_step = 101, loss = 0.117357, precision = 1.0, recall = 1.0
# WARNING:tensorflow:Skipping summary for global_step, must be a float or np.float32.
# INFO:tensorflow:Validation (step 150): loss = 0.117357, accuracy = 0.966667, precision = 1.0, recall = 1.0, global_step = 101
# INFO:tensorflow:Saving checkpoints for 151 into ./iris_model/model.ckpt.
# WARNING:tensorflow:From /Users/ihuangyiran/anaconda2/envs/py3-tf/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:662: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with x is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From /Users/ihuangyiran/anaconda2/envs/py3-tf/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:662: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with y is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From /Users/ihuangyiran/anaconda2/envs/py3-tf/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/estimators/head.py:615: scalar_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.scalar. Note that tf.summary.scalar uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on the scope they are created in. Also, passing a tensor or list of tags to a scalar summary op is no longer supported.
# INFO:tensorflow:Starting evaluation at 2017-06-12-14:21:10
# INFO:tensorflow:Restoring parameters from ./iris_model/model.ckpt-151
# INFO:tensorflow:Finished evaluation at 2017-06-12-14:21:10
# INFO:tensorflow:Saving dict for global step 151: accuracy = 0.966667, global_step = 151, loss = 0.0778256, precision = 1.0, recall = 1.0
# WARNING:tensorflow:Skipping summary for global_step, must be a float or np.float32.
# INFO:tensorflow:Validation (step 200): loss = 0.0778256, accuracy = 0.966667, precision = 1.0, recall = 1.0, global_step = 151
# INFO:tensorflow:Saving checkpoints for 201 into ./iris_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 44.977
# INFO:tensorflow:loss = 0.072221, step = 201 (2.223 sec)
# WARNING:tensorflow:From /Users/ihuangyiran/anaconda2/envs/py3-tf/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:662: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with x is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From /Users/ihuangyiran/anaconda2/envs/py3-tf/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:662: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with y is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From /Users/ihuangyiran/anaconda2/envs/py3-tf/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/estimators/head.py:615: scalar_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.scalar. Note that tf.summary.scalar uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on the scope they are created in. Also, passing a tensor or list of tags to a scalar summary op is no longer supported.
# INFO:tensorflow:Starting evaluation at 2017-06-12-14:21:11
# INFO:tensorflow:Restoring parameters from ./iris_model/model.ckpt-201
# INFO:tensorflow:Finished evaluation at 2017-06-12-14:21:11
# INFO:tensorflow:Saving dict for global step 201: accuracy = 0.966667, global_step = 201, loss = 0.0725049, precision = 1.0, recall = 1.0
# WARNING:tensorflow:Skipping summary for global_step, must be a float or np.float32.
# INFO:tensorflow:Validation (step 250): loss = 0.0725049, accuracy = 0.966667, precision = 1.0, recall = 1.0, global_step = 201
# INFO:tensorflow:Saving checkpoints for 251 into ./iris_model/model.ckpt.
# WARNING:tensorflow:From /Users/ihuangyiran/anaconda2/envs/py3-tf/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:662: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with x is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From /Users/ihuangyiran/anaconda2/envs/py3-tf/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:662: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with y is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From /Users/ihuangyiran/anaconda2/envs/py3-tf/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/estimators/head.py:615: scalar_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.scalar. Note that tf.summary.scalar uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on the scope they are created in. Also, passing a tensor or list of tags to a scalar summary op is no longer supported.
# INFO:tensorflow:Starting evaluation at 2017-06-12-14:21:12
# INFO:tensorflow:Restoring parameters from ./iris_model/model.ckpt-251
# INFO:tensorflow:Finished evaluation at 2017-06-12-14:21:12
# INFO:tensorflow:Saving dict for global step 251: accuracy = 0.966667, global_step = 251, loss = 0.0639563, precision = 1.0, recall = 1.0
# WARNING:tensorflow:Skipping summary for global_step, must be a float or np.float32.
# INFO:tensorflow:Validation (step 300): loss = 0.0639563, accuracy = 0.966667, precision = 1.0, recall = 1.0, global_step = 251
# INFO:tensorflow:Saving checkpoints for 301 into ./iris_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 45.82
# INFO:tensorflow:loss = 0.0645416, step = 301 (2.183 sec)
# WARNING:tensorflow:From /Users/ihuangyiran/anaconda2/envs/py3-tf/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:662: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with x is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From /Users/ihuangyiran/anaconda2/envs/py3-tf/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:662: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with y is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From /Users/ihuangyiran/anaconda2/envs/py3-tf/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/estimators/head.py:615: scalar_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.scalar. Note that tf.summary.scalar uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on the scope they are created in. Also, passing a tensor or list of tags to a scalar summary op is no longer supported.
# INFO:tensorflow:Starting evaluation at 2017-06-12-14:21:13
# INFO:tensorflow:Restoring parameters from ./iris_model/model.ckpt-301
# INFO:tensorflow:Finished evaluation at 2017-06-12-14:21:13
# INFO:tensorflow:Saving dict for global step 301: accuracy = 0.966667, global_step = 301, loss = 0.0619594, precision = 1.0, recall = 1.0
# WARNING:tensorflow:Skipping summary for global_step, must be a float or np.float32.
# INFO:tensorflow:Validation (step 350): loss = 0.0619594, accuracy = 0.966667, precision = 1.0, recall = 1.0, global_step = 301
# INFO:tensorflow:Saving checkpoints for 351 into ./iris_model/model.ckpt.
# WARNING:tensorflow:From /Users/ihuangyiran/anaconda2/envs/py3-tf/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:662: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with x is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From /Users/ihuangyiran/anaconda2/envs/py3-tf/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:662: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with y is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From /Users/ihuangyiran/anaconda2/envs/py3-tf/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/estimators/head.py:615: scalar_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.scalar. Note that tf.summary.scalar uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on the scope they are created in. Also, passing a tensor or list of tags to a scalar summary op is no longer supported.
# INFO:tensorflow:Starting evaluation at 2017-06-12-14:21:14
# INFO:tensorflow:Restoring parameters from ./iris_model/model.ckpt-351
# INFO:tensorflow:Finished evaluation at 2017-06-12-14:21:14
# INFO:tensorflow:Saving dict for global step 351: accuracy = 0.966667, global_step = 351, loss = 0.0584743, precision = 1.0, recall = 1.0
# WARNING:tensorflow:Skipping summary for global_step, must be a float or np.float32.
# INFO:tensorflow:Validation (step 400): loss = 0.0584743, accuracy = 0.966667, precision = 1.0, recall = 1.0, global_step = 351
# INFO:tensorflow:Saving checkpoints for 401 into ./iris_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 46.7062
# INFO:tensorflow:loss = 0.0602015, step = 401 (2.141 sec)
# WARNING:tensorflow:From /Users/ihuangyiran/anaconda2/envs/py3-tf/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:662: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with x is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From /Users/ihuangyiran/anaconda2/envs/py3-tf/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:662: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with y is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From /Users/ihuangyiran/anaconda2/envs/py3-tf/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/estimators/head.py:615: scalar_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.scalar. Note that tf.summary.scalar uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on the scope they are created in. Also, passing a tensor or list of tags to a scalar summary op is no longer supported.
# INFO:tensorflow:Starting evaluation at 2017-06-12-14:21:15
# INFO:tensorflow:Restoring parameters from ./iris_model/model.ckpt-401
# INFO:tensorflow:Finished evaluation at 2017-06-12-14:21:16
# INFO:tensorflow:Saving dict for global step 401: accuracy = 0.966667, global_step = 401, loss = 0.0569063, precision = 1.0, recall = 1.0
# WARNING:tensorflow:Skipping summary for global_step, must be a float or np.float32.
# INFO:tensorflow:Validation (step 450): loss = 0.0569063, accuracy = 0.966667, precision = 1.0, recall = 1.0, global_step = 401
# INFO:tensorflow:Saving checkpoints for 451 into ./iris_model/model.ckpt.
# WARNING:tensorflow:From /Users/ihuangyiran/anaconda2/envs/py3-tf/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:662: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with x is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From /Users/ihuangyiran/anaconda2/envs/py3-tf/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:662: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with y is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From /Users/ihuangyiran/anaconda2/envs/py3-tf/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/estimators/head.py:615: scalar_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.scalar. Note that tf.summary.scalar uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on the scope they are created in. Also, passing a tensor or list of tags to a scalar summary op is no longer supported.
# INFO:tensorflow:Starting evaluation at 2017-06-12-14:21:16
# INFO:tensorflow:Restoring parameters from ./iris_model/model.ckpt-451
# INFO:tensorflow:Finished evaluation at 2017-06-12-14:21:17
# INFO:tensorflow:Saving dict for global step 451: accuracy = 0.966667, global_step = 451, loss = 0.0557249, precision = 1.0, recall = 1.0
# WARNING:tensorflow:Skipping summary for global_step, must be a float or np.float32.
# INFO:tensorflow:Validation (step 500): loss = 0.0557249, accuracy = 0.966667, precision = 1.0, recall = 1.0, global_step = 451
# INFO:tensorflow:Saving checkpoints for 501 into ./iris_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 45.3162
# INFO:tensorflow:loss = 0.0574461, step = 501 (2.207 sec)
# WARNING:tensorflow:From /Users/ihuangyiran/anaconda2/envs/py3-tf/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:662: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with x is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From /Users/ihuangyiran/anaconda2/envs/py3-tf/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:662: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with y is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From /Users/ihuangyiran/anaconda2/envs/py3-tf/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/estimators/head.py:615: scalar_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.scalar. Note that tf.summary.scalar uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on the scope they are created in. Also, passing a tensor or list of tags to a scalar summary op is no longer supported.
# INFO:tensorflow:Starting evaluation at 2017-06-12-14:21:17
# INFO:tensorflow:Restoring parameters from ./iris_model/model.ckpt-501
# INFO:tensorflow:Finished evaluation at 2017-06-12-14:21:18
# INFO:tensorflow:Saving dict for global step 501: accuracy = 0.933333, global_step = 501, loss = 0.0546066, precision = 1.0, recall = 1.0
# WARNING:tensorflow:Skipping summary for global_step, must be a float or np.float32.
# INFO:tensorflow:Validation (step 550): loss = 0.0546066, accuracy = 0.933333, precision = 1.0, recall = 1.0, global_step = 501
# INFO:tensorflow:Saving checkpoints for 551 into ./iris_model/model.ckpt.
# WARNING:tensorflow:From /Users/ihuangyiran/anaconda2/envs/py3-tf/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:662: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with x is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From /Users/ihuangyiran/anaconda2/envs/py3-tf/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:662: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with y is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From /Users/ihuangyiran/anaconda2/envs/py3-tf/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/estimators/head.py:615: scalar_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.scalar. Note that tf.summary.scalar uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on the scope they are created in. Also, passing a tensor or list of tags to a scalar summary op is no longer supported.
# INFO:tensorflow:Starting evaluation at 2017-06-12-14:21:18
# INFO:tensorflow:Restoring parameters from ./iris_model/model.ckpt-551
# INFO:tensorflow:Finished evaluation at 2017-06-12-14:21:19
# INFO:tensorflow:Saving dict for global step 551: accuracy = 0.933333, global_step = 551, loss = 0.0539396, precision = 1.0, recall = 1.0
# WARNING:tensorflow:Skipping summary for global_step, must be a float or np.float32.
# INFO:tensorflow:Validation (step 600): loss = 0.0539396, accuracy = 0.933333, precision = 1.0, recall = 1.0, global_step = 551
# INFO:tensorflow:Saving checkpoints for 601 into ./iris_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 44.8874
# INFO:tensorflow:loss = 0.0554834, step = 601 (2.228 sec)
# WARNING:tensorflow:From /Users/ihuangyiran/anaconda2/envs/py3-tf/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:662: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with x is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From /Users/ihuangyiran/anaconda2/envs/py3-tf/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:662: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with y is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From /Users/ihuangyiran/anaconda2/envs/py3-tf/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/estimators/head.py:615: scalar_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.scalar. Note that tf.summary.scalar uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on the scope they are created in. Also, passing a tensor or list of tags to a scalar summary op is no longer supported.
# INFO:tensorflow:Starting evaluation at 2017-06-12-14:21:20
# INFO:tensorflow:Restoring parameters from ./iris_model/model.ckpt-601
# INFO:tensorflow:Finished evaluation at 2017-06-12-14:21:20
# INFO:tensorflow:Saving dict for global step 601: accuracy = 0.933333, global_step = 601, loss = 0.0535129, precision = 1.0, recall = 1.0
# WARNING:tensorflow:Skipping summary for global_step, must be a float or np.float32.
# INFO:tensorflow:Validation (step 650): loss = 0.0535129, accuracy = 0.933333, precision = 1.0, recall = 1.0, global_step = 601
# INFO:tensorflow:Saving checkpoints for 651 into ./iris_model/model.ckpt.
# WARNING:tensorflow:From /Users/ihuangyiran/anaconda2/envs/py3-tf/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:662: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with x is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From /Users/ihuangyiran/anaconda2/envs/py3-tf/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:662: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with y is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From /Users/ihuangyiran/anaconda2/envs/py3-tf/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/estimators/head.py:615: scalar_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.scalar. Note that tf.summary.scalar uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on the scope they are created in. Also, passing a tensor or list of tags to a scalar summary op is no longer supported.
# INFO:tensorflow:Starting evaluation at 2017-06-12-14:21:21
# INFO:tensorflow:Restoring parameters from ./iris_model/model.ckpt-651
# INFO:tensorflow:Finished evaluation at 2017-06-12-14:21:21
# INFO:tensorflow:Saving dict for global step 651: accuracy = 0.933333, global_step = 651, loss = 0.0531871, precision = 1.0, recall = 1.0
# WARNING:tensorflow:Skipping summary for global_step, must be a float or np.float32.
# INFO:tensorflow:Validation (step 700): loss = 0.0531871, accuracy = 0.933333, precision = 1.0, recall = 1.0, global_step = 651
# INFO:tensorflow:Saving checkpoints for 701 into ./iris_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 45.7996
# INFO:tensorflow:loss = 0.0538604, step = 701 (2.183 sec)
# WARNING:tensorflow:From /Users/ihuangyiran/anaconda2/envs/py3-tf/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:662: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with x is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From /Users/ihuangyiran/anaconda2/envs/py3-tf/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:662: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with y is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From /Users/ihuangyiran/anaconda2/envs/py3-tf/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/estimators/head.py:615: scalar_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.scalar. Note that tf.summary.scalar uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on the scope they are created in. Also, passing a tensor or list of tags to a scalar summary op is no longer supported.
# INFO:tensorflow:Starting evaluation at 2017-06-12-14:21:22
# INFO:tensorflow:Restoring parameters from ./iris_model/model.ckpt-701
# INFO:tensorflow:Finished evaluation at 2017-06-12-14:21:22
# INFO:tensorflow:Saving dict for global step 701: accuracy = 0.966667, global_step = 701, loss = 0.0529583, precision = 1.0, recall = 1.0
# WARNING:tensorflow:Skipping summary for global_step, must be a float or np.float32.
# INFO:tensorflow:Validation (step 750): loss = 0.0529583, accuracy = 0.966667, precision = 1.0, recall = 1.0, global_step = 701
# INFO:tensorflow:Saving checkpoints for 751 into ./iris_model/model.ckpt.
# WARNING:tensorflow:From /Users/ihuangyiran/anaconda2/envs/py3-tf/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:662: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with x is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From /Users/ihuangyiran/anaconda2/envs/py3-tf/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:662: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with y is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From /Users/ihuangyiran/anaconda2/envs/py3-tf/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/estimators/head.py:615: scalar_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.scalar. Note that tf.summary.scalar uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on the scope they are created in. Also, passing a tensor or list of tags to a scalar summary op is no longer supported.
# INFO:tensorflow:Starting evaluation at 2017-06-12-14:21:23
# INFO:tensorflow:Restoring parameters from ./iris_model/model.ckpt-751
# INFO:tensorflow:Finished evaluation at 2017-06-12-14:21:23
# INFO:tensorflow:Saving dict for global step 751: accuracy = 0.966667, global_step = 751, loss = 0.0528705, precision = 1.0, recall = 1.0
# WARNING:tensorflow:Skipping summary for global_step, must be a float or np.float32.
# INFO:tensorflow:Validation (step 800): loss = 0.0528705, accuracy = 0.966667, precision = 1.0, recall = 1.0, global_step = 751
# INFO:tensorflow:Saving checkpoints for 801 into ./iris_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 45.4777
# INFO:tensorflow:loss = 0.0523459, step = 801 (2.199 sec)
# WARNING:tensorflow:From /Users/ihuangyiran/anaconda2/envs/py3-tf/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:662: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with x is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From /Users/ihuangyiran/anaconda2/envs/py3-tf/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:662: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with y is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From /Users/ihuangyiran/anaconda2/envs/py3-tf/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/estimators/head.py:615: scalar_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.scalar. Note that tf.summary.scalar uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on the scope they are created in. Also, passing a tensor or list of tags to a scalar summary op is no longer supported.
# INFO:tensorflow:Starting evaluation at 2017-06-12-14:21:24
# INFO:tensorflow:Restoring parameters from ./iris_model/model.ckpt-801
# INFO:tensorflow:Finished evaluation at 2017-06-12-14:21:24
# INFO:tensorflow:Saving dict for global step 801: accuracy = 0.966667, global_step = 801, loss = 0.0528436, precision = 1.0, recall = 1.0
# WARNING:tensorflow:Skipping summary for global_step, must be a float or np.float32.
# INFO:tensorflow:Validation (step 850): loss = 0.0528436, accuracy = 0.966667, precision = 1.0, recall = 1.0, global_step = 801
# INFO:tensorflow:Saving checkpoints for 851 into ./iris_model/model.ckpt.
# WARNING:tensorflow:From /Users/ihuangyiran/anaconda2/envs/py3-tf/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:662: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with x is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From /Users/ihuangyiran/anaconda2/envs/py3-tf/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:662: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with y is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From /Users/ihuangyiran/anaconda2/envs/py3-tf/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/estimators/head.py:615: scalar_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.scalar. Note that tf.summary.scalar uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on the scope they are created in. Also, passing a tensor or list of tags to a scalar summary op is no longer supported.
# INFO:tensorflow:Starting evaluation at 2017-06-12-14:21:25
# INFO:tensorflow:Restoring parameters from ./iris_model/model.ckpt-851
# INFO:tensorflow:Finished evaluation at 2017-06-12-14:21:25
# INFO:tensorflow:Saving dict for global step 851: accuracy = 0.966667, global_step = 851, loss = 0.0528102, precision = 1.0, recall = 1.0
# WARNING:tensorflow:Skipping summary for global_step, must be a float or np.float32.
# INFO:tensorflow:Validation (step 900): loss = 0.0528102, accuracy = 0.966667, precision = 1.0, recall = 1.0, global_step = 851
# INFO:tensorflow:Saving checkpoints for 901 into ./iris_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 44.8144
# INFO:tensorflow:loss = 0.0511946, step = 901 (2.231 sec)
# WARNING:tensorflow:From /Users/ihuangyiran/anaconda2/envs/py3-tf/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:662: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with x is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From /Users/ihuangyiran/anaconda2/envs/py3-tf/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:662: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with y is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From /Users/ihuangyiran/anaconda2/envs/py3-tf/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/estimators/head.py:615: scalar_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.scalar. Note that tf.summary.scalar uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on the scope they are created in. Also, passing a tensor or list of tags to a scalar summary op is no longer supported.
# INFO:tensorflow:Starting evaluation at 2017-06-12-14:21:26
# INFO:tensorflow:Restoring parameters from ./iris_model/model.ckpt-901
# INFO:tensorflow:Finished evaluation at 2017-06-12-14:21:27
# INFO:tensorflow:Saving dict for global step 901: accuracy = 0.966667, global_step = 901, loss = 0.0527846, precision = 1.0, recall = 1.0
# WARNING:tensorflow:Skipping summary for global_step, must be a float or np.float32.
# INFO:tensorflow:Validation (step 950): loss = 0.0527846, accuracy = 0.966667, precision = 1.0, recall = 1.0, global_step = 901
# INFO:tensorflow:Saving checkpoints for 951 into ./iris_model/model.ckpt.
# WARNING:tensorflow:From /Users/ihuangyiran/anaconda2/envs/py3-tf/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:662: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with x is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From /Users/ihuangyiran/anaconda2/envs/py3-tf/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:662: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with y is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From /Users/ihuangyiran/anaconda2/envs/py3-tf/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/estimators/head.py:615: scalar_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.scalar. Note that tf.summary.scalar uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on the scope they are created in. Also, passing a tensor or list of tags to a scalar summary op is no longer supported.
# INFO:tensorflow:Starting evaluation at 2017-06-12-14:21:27
# INFO:tensorflow:Restoring parameters from ./iris_model/model.ckpt-951
# INFO:tensorflow:Finished evaluation at 2017-06-12-14:21:28
# INFO:tensorflow:Saving dict for global step 951: accuracy = 0.966667, global_step = 951, loss = 0.0528065, precision = 1.0, recall = 1.0
# WARNING:tensorflow:Skipping summary for global_step, must be a float or np.float32.
# INFO:tensorflow:Validation (step 1000): loss = 0.0528065, accuracy = 0.966667, precision = 1.0, recall = 1.0, global_step = 951
# INFO:tensorflow:Saving checkpoints for 1001 into ./iris_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 45.0833
# INFO:tensorflow:loss = 0.0500987, step = 1001 (2.218 sec)
# WARNING:tensorflow:From /Users/ihuangyiran/anaconda2/envs/py3-tf/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:662: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with x is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From /Users/ihuangyiran/anaconda2/envs/py3-tf/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:662: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with y is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From /Users/ihuangyiran/anaconda2/envs/py3-tf/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/estimators/head.py:615: scalar_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.scalar. Note that tf.summary.scalar uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on the scope they are created in. Also, passing a tensor or list of tags to a scalar summary op is no longer supported.
# INFO:tensorflow:Starting evaluation at 2017-06-12-14:21:28
# INFO:tensorflow:Restoring parameters from ./iris_model/model.ckpt-1001
# INFO:tensorflow:Finished evaluation at 2017-06-12-14:21:29
# INFO:tensorflow:Saving dict for global step 1001: accuracy = 0.966667, global_step = 1001, loss = 0.0529313, precision = 1.0, recall = 1.0
# WARNING:tensorflow:Skipping summary for global_step, must be a float or np.float32.
# INFO:tensorflow:Validation (step 1050): loss = 0.0529313, accuracy = 0.966667, precision = 1.0, recall = 1.0, global_step = 1001
# INFO:tensorflow:Saving checkpoints for 1051 into ./iris_model/model.ckpt.
# WARNING:tensorflow:From /Users/ihuangyiran/anaconda2/envs/py3-tf/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:662: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with x is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From /Users/ihuangyiran/anaconda2/envs/py3-tf/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:662: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with y is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From /Users/ihuangyiran/anaconda2/envs/py3-tf/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/estimators/head.py:615: scalar_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.scalar. Note that tf.summary.scalar uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on the scope they are created in. Also, passing a tensor or list of tags to a scalar summary op is no longer supported.
# INFO:tensorflow:Starting evaluation at 2017-06-12-14:21:29
# INFO:tensorflow:Restoring parameters from ./iris_model/model.ckpt-1051
# INFO:tensorflow:Finished evaluation at 2017-06-12-14:21:30
# INFO:tensorflow:Saving dict for global step 1051: accuracy = 0.966667, global_step = 1051, loss = 0.0531289, precision = 1.0, recall = 1.0
# WARNING:tensorflow:Skipping summary for global_step, must be a float or np.float32.
# INFO:tensorflow:Validation (step 1100): loss = 0.0531289, accuracy = 0.966667, precision = 1.0, recall = 1.0, global_step = 1051
# INFO:tensorflow:Saving checkpoints for 1101 into ./iris_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 45.5276
# INFO:tensorflow:loss = 0.0490633, step = 1101 (2.197 sec)
# WARNING:tensorflow:From /Users/ihuangyiran/anaconda2/envs/py3-tf/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:662: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with x is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From /Users/ihuangyiran/anaconda2/envs/py3-tf/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:662: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with y is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From /Users/ihuangyiran/anaconda2/envs/py3-tf/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/estimators/head.py:615: scalar_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.scalar. Note that tf.summary.scalar uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on the scope they are created in. Also, passing a tensor or list of tags to a scalar summary op is no longer supported.
# INFO:tensorflow:Starting evaluation at 2017-06-12-14:21:31
# INFO:tensorflow:Restoring parameters from ./iris_model/model.ckpt-1101
# INFO:tensorflow:Finished evaluation at 2017-06-12-14:21:31
# INFO:tensorflow:Saving dict for global step 1101: accuracy = 0.966667, global_step = 1101, loss = 0.0532425, precision = 1.0, recall = 1.0
# WARNING:tensorflow:Skipping summary for global_step, must be a float or np.float32.
# INFO:tensorflow:Validation (step 1150): loss = 0.0532425, accuracy = 0.966667, precision = 1.0, recall = 1.0, global_step = 1101
# INFO:tensorflow:Stopping. Best step: 950 with loss = 0.05278458818793297.
# INFO:tensorflow:Saving checkpoints for 1150 into ./iris_model/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.0487048.
# WARNING:tensorflow:From /Users/ihuangyiran/anaconda2/envs/py3-tf/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/estimators/head.py:615: scalar_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.scalar. Note that tf.summary.scalar uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on the scope they are created in. Also, passing a tensor or list of tags to a scalar summary op is no longer supported.
# INFO:tensorflow:Starting evaluation at 2017-06-12-14:21:31
# INFO:tensorflow:Restoring parameters from ./iris_model/model.ckpt-1150
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finished evaluation at 2017-06-12-14:21:32
# INFO:tensorflow:Saving dict for global step 1150: accuracy = 0.966667, global_step = 1150, loss = 0.0577823
# WARNING:tensorflow:Skipping summary for global_step, must be a float or np.float32.
#
# Test Accuracy:  0.966667
#
# WARNING:tensorflow:From /Users/ihuangyiran/anaconda2/envs/py3-tf/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:335: calling DNNClassifier.predict (from tensorflow.contrib.learn.python.learn.estimators.dnn) with outputs=None is deprecated and will be removed after 2017-03-01.
# Instructions for updating:
# Please switch to predict_classes, or set `outputs` argument.
# INFO:tensorflow:Restoring parameters from ./iris_model/model.ckpt-1150
# New Sample, Class Prediction:    [1, 2]
